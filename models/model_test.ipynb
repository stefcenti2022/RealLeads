# %%
import pandas as pd
import json

# %%
class IdTable:
    def __init__(self, path):
        self.name = 'id_table_clean'
        self.csvfile = path + self.name + '.csv'
        self.df = pd.read_csv(self.csvfile)

    def read_all(self):
        return json.loads(self.df.to_json(orient='records'))
    
    def read(self, mls_number):
        results = self.df.loc[self.df['MLSNumber'] == mls_number]

        return json.loads(results.to_json(orient='records'))

# %%
def get_id_table_model(mls_number):
    model = IdTable('../Resources/data/')

    return model.read(mls_number)

# %%
def get_id_table_model_all():
    model = IdTable('../Resources/data/')
    
    return model.read_all()

# %%
results = get_id_table_model('DENC518086')

res
# Out:
# [{'MLSNumber': 'DENC518086',
#   'Address': '2615 Pecksniff Rd',
#   'Category': 'RES',
#   'City': 'Wilmingon',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'SHERWOOD PARK II',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None}]

# %%
res[0]['MLSNumber']
# Out:
# 'DENC518086'

# %%
results = get_id_table_model('DENC518982')

results
# Out:
# [{'MLSNumber': 'DENC518982',
#   'Address': '4938 S Tupelo Turn',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'PEPPER RIDGE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None}]

# %%
results = get_id_table_model_all()

results
# Out:
# [{'MLSNumber': 'DENC518086',
#   'Address': '2615 Pecksniff Rd',
#   'Category': 'RES',
#   'City': 'Wilmingon',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'SHERWOOD PARK II',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC518982',
#   'Address': '4938 S Tupelo Turn',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'PEPPER RIDGE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC512992',
#   'Address': '15 Kristina Ct',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'WOODMILL',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC512104',
#   'Address': '3251 Champions Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAIRWAY FALLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC503480',
#   'Address': '3706 Lafayette St',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'WASHINGTON HEIGHTS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC501458',
#   'Address': '3425 Cranston Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'CRANSTON HEIGHTS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC495076',
#   'Address': '2409 E Parris Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'CEDARCREST',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC506356',
#   'Address': '1802 Fenpor Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'WASHINGTON HEIGHTS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC524092',
#   'Address': '4309 Birch Cir',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'BIRCH POINTE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Linden Hill',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'Dickinson'},
#  {'MLSNumber': 'DENC523094',
#   'Address': '5822 Pepper Ridge Ct',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'PEPPER RIDGE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC501750',
#   'Address': '3220 Champions Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAIRWAY FALLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Linden Hill',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'John Dickinson'},
#  {'MLSNumber': 'DENC505216',
#   'Address': '424 Centerville Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'BROOKLAND TERRACE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC500680',
#   'Address': '3420 Cranston Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'CRANSTON HEIGHTS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Marbrook',
#   'Schools-Middle': 'Alexis I. Du Pont',
#   'Schools-HighSchool': 'Mckean'},
#  {'MLSNumber': 'DENC521992',
#   'Address': '3 Carolina Ct',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'WOODMILL',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC523212',
#   'Address': '3411 Haley Ct',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'BIRCH POINTE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC512816',
#   'Address': '4940 Mermaid Blvd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'PEPPER RIDGE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Linden Hill',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'John Dickinson'},
#  {'MLSNumber': 'DENC510414',
#   'Address': '1108 Braken Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'BERKSHIRE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC517606',
#   'Address': '5099 W Woodmill Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'WOODMILL',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC508042',
#   'Address': '4936 Tupelo Turn',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'PEPPER RIDGE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Linden Hil',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'Dickinson'},
#  {'MLSNumber': 'DENC500644',
#   'Address': '5059 E Woodmill Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'WOODMILL',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC522324',
#   'Address': '5018 E Woodmill Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'WOODMILL',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Heritage',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'Dickinson'},
#  {'MLSNumber': 'DENC519198',
#   'Address': '4976 Mermaid Blvd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'PEPPER RIDGE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Linden Hill',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'John Dickinson'},
#  {'MLSNumber': 'DENC507636',
#   'Address': '5417 Jenmatt Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'LINDEN HILL SQUARE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Linden Hill',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'Dickinson'},
#  {'MLSNumber': 'DENC509542',
#   'Address': '5409 Jenmatt Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'LINDEN HILL SQUARE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC505724',
#   'Address': '3010 Charing Cross',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'BERKSHIRE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC505084',
#   'Address': '2004 Louisa Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'EASTBURN ACRES',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC523372',
#   'Address': '5026 N Tupelo Turn',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'PEPPER RIDGE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC520810',
#   'Address': '11 Kristina Ct',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'WOODMILL',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC509390',
#   'Address': '1902 Lincoln Ave.',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'CRANSTON HEIGHTS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC499486',
#   'Address': '1118 Braken Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'BERKSHIRE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC511264',
#   'Address': '3221 Brookline Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAIRWAY FALLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Linden Hill',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'John Dickinson'},
#  {'MLSNumber': 'DENC502798',
#   'Address': '1114 Braken Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'BERKSHIRE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC521912',
#   'Address': '2309 Katherine Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'DUNLINDEN ACRES',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC507666',
#   'Address': '1223 Gilbert Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'CAPITAL TR FMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC503534',
#   'Address': '5405 Doral Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAIRWAY FALLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Linden Hill',
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC501980',
#   'Address': '4613 Springers Ln',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'LIMESTONE ACRES',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Heritage',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'Dickinson'},
#  {'MLSNumber': 'DENC501462',
#   'Address': '2006 Duncan Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'NONE AVAILABLE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC507686',
#   'Address': '3818 Evelyn Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'DUNLINDEN ACRES',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC508130',
#   'Address': '1522 Braken Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'BERKSHIRE LIMESTON',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC507822',
#   'Address': '3813 Evelyn Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'DUNLINDEN ACRES',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Anna P. Mote',
#   'Schools-Middle': 'Stanton',
#   'Schools-HighSchool': 'Mckean'},
#  {'MLSNumber': 'DENC520716',
#   'Address': '3235 Brookline Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAIRWAY FALLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Linden Hill',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'John Dickinson'},
#  {'MLSNumber': 'DENC512480',
#   'Address': '3419 Pebble Beach Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAIRWAY FALLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC497602',
#   'Address': '4917 Hogan Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'VILLAGE OF PLUM RU',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC511338',
#   'Address': '3214 Champions Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAIRWAY FALLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC510466',
#   'Address': '1009 Highland Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'CAPITAL TR FMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC524506',
#   'Address': '10 Kristina Ct',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'WOODMILL',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC523362',
#   'Address': '2406 Duncan Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'NONE AVAILABLE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC521672',
#   'Address': '2411 Hammond Pl',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'KIRKWOOD GARDENS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC509908',
#   'Address': '2218 Alister Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'FAULKLAND HEIGHTS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC520624',
#   'Address': '22 Ingrid Ct',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'WOODMILL',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC522354',
#   'Address': '2317 Katherine Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'DUNLINDEN ACRES',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Evan G. Shortlidge Academy',
#   'Schools-Middle': 'Stanton',
#   'Schools-HighSchool': 'Thomas Mckean'},
#  {'MLSNumber': 'DENC518048',
#   'Address': '4401 Sandy Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'KLAIR ESTATES',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC513006',
#   'Address': '2408 Owen Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'KIRKWOOD GARDENS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Heritage',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'Mckean'},
#  {'MLSNumber': 'DENC508044',
#   'Address': '5901 Old Capitol Trl',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30905.0,
#   'Subdivision': 'EASTBURN HEIGHTS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC510684',
#   'Address': '3228 Brookline Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAIRWAY FALLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC520348',
#   'Address': '3205 Brookline Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAIRWAY FALLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Linden Hill',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'John Dickinson'},
#  {'MLSNumber': 'DENC500064',
#   'Address': '2425 E Parris Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'CEDARCREST',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Mote',
#   'Schools-Middle': 'Stanton',
#   'Schools-HighSchool': 'Mckean'},
#  {'MLSNumber': 'DENC498974',
#   'Address': '2210 Alister Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAULKLAND HEIGHTS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC517252',
#   'Address': '4520 Hendry Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'KLAIR ESTATES',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC523606',
#   'Address': '3253 Champions Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAIRWAY FALLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC522204',
#   'Address': '6 Sandybrae Ct',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'LINDEN GREEN',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC520338',
#   'Address': '4 Penndrew Ct',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'PENN DREW MANOR',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC523950',
#   'Address': '4809 Weatherhill Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'WEATHERHILL FARMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC518792',
#   'Address': '5545 Doral Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAIRWAY FALLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC518678',
#   'Address': '6018 Old Capitol Trl',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'NONE AVAILABLE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC509076',
#   'Address': '2644 Drayton Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30906.0,
#   'Subdivision': 'HERITAGE PARK',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC503958',
#   'Address': '2125 Elder Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'ALBERTSON PARK',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC501174',
#   'Address': '3828 Katherine Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'DUNLINDEN ACRES',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC517408',
#   'Address': '4752 Weatherhill Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'WEATHERHILL FARMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC505992',
#   'Address': '2619 Salem Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'MONTCLARE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Heritage',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'John Dickinson'},
#  {'MLSNumber': 'DENC502848',
#   'Address': '4950 S Raintree Ct',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'PEPPER RIDGE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Linden Hill',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'Dickinson'},
#  {'MLSNumber': 'DENC517542',
#   'Address': '4432 Sandy Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'KLAIR ESTATES',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC512400',
#   'Address': '3225 Champions Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAIRWAY FALLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Linden Hill',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC508204',
#   'Address': '1111 Highland Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'MARSHALLTON',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC502158',
#   'Address': '1212 Lorrain Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'CAPITAL TR FMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC500764',
#   'Address': '2721 Westlock Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'SHERWOOD PARK II',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC508476',
#   'Address': '3424 Pebble Beach Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAIRWAY FALLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC523874',
#   'Address': '3815 Hutchison Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'DUNLINDEN ACRES',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC517754',
#   'Address': '4864 Weatherhill Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'WEATHERHILL FARMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC499872',
#   'Address': '4708 Old Capitol Trl',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'DELPARK MANOR',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC505060',
#   'Address': '2218 Saint Francis St',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'VILLAGE OF LINDELL',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Heritage',
#   'Schools-Middle': 'Stanton',
#   'Schools-HighSchool': 'John Dickinson'},
#  {'MLSNumber': 'DENC523916',
#   'Address': '3240 Champions Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAIRWAY FALLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Linden Hill',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'John Dickinson'},
#  {'MLSNumber': 'DENC523336',
#   'Address': '2408 Faulkland Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAULKLAND HEIGHTS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Marbrook',
#   'Schools-Middle': 'Alexis I. Du Pont',
#   'Schools-HighSchool': 'Mckean'},
#  {'MLSNumber': 'DENC510198',
#   'Address': '4622 Muggleton Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'LIMESTONE ACRES',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC502980',
#   'Address': '4720 Weatherhill Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'WEATHERHILL FARMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC500324',
#   'Address': '152 Steven Ln',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'LIMESTONE HILLS WEST',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC501922',
#   'Address': '2853 E Oakland Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'BRANDYWINE SPRINGS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC501074',
#   'Address': '3412 Pebble Beach Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAIRWAY FALLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Linden Hill',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'John Dickinson'},
#  {'MLSNumber': 'DENC502326',
#   'Address': '2395 Nicholby Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30904.0,
#   'Subdivision': 'LIMESTONE GARDENS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Heritage',
#   'Schools-Middle': 'Stanton',
#   'Schools-HighSchool': 'John Dickinson'},
#  {'MLSNumber': 'DENC524374',
#   'Address': '1809 Marshall Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'CRANSTON HEIGHTS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC521594',
#   'Address': '3406 Pebble Beach Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAIRWAY FALLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC518582',
#   'Address': '3201-Unit Falcon Ln',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'STONEY BATTER',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC518650',
#   'Address': '4728 Weatherhill Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'WEATHERHILL FARMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Linden Hill',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'Dickinson'},
#  {'MLSNumber': 'DENC512722',
#   'Address': '2721 Bardell Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'SHERWOOD PARK II',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC512084',
#   'Address': '3712 Wild Cherry Ln',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30906.0,
#   'Subdivision': 'DUNCAN WOODS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC511666',
#   'Address': '2410 Tapley Ln',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'LIMESTONE ACRES',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC511004',
#   'Address': '32 Whitehall Cir',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'KLAIR ESTATES',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Forest Oak',
#   'Schools-Middle': 'Stanton',
#   'Schools-HighSchool': 'John Dickinson'},
#  {'MLSNumber': 'DENC501862',
#   'Address': '2676 Whitman Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'HERITAGE PARK',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC498786',
#   'Address': '4747 Weatherhill Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'WEATHERHILL FARMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC517190',
#   'Address': '2621 Skylark Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'BROOKMEADE II',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC512534',
#   'Address': '4771 Weatherhill Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'WEATHERHILL FARMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Linden Hill',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'Dickinson'},
#  {'MLSNumber': 'DENC509920',
#   'Address': '2727 Newell Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAULKLAND HEIGHTS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC511208',
#   'Address': '1603 London Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30906.0,
#   'Subdivision': 'AVALON',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC509770',
#   'Address': '2426 E Eric Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'MAPLECREST',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC505268',
#   'Address': '2616 Dean Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAULKLAND HEIGHTS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Marbrook',
#   'Schools-Middle': 'Dupont A',
#   'Schools-HighSchool': 'Mckean'},
#  {'MLSNumber': 'DENC504370',
#   'Address': '2207 E Huntington Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'PINECREST',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC504172',
#   'Address': '2410 Owen Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'KIRKWOOD GARDENS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC518736',
#   'Address': '1317 Chalet Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'MARSHALLTON HGTS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Mote',
#   'Schools-Middle': 'Stanton',
#   'Schools-HighSchool': 'Mckean'},
#  {'MLSNumber': 'DENC502990',
#   'Address': '2419 Hartley Pl',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'MAPLECREST',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Heritage',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'Mckean'},
#  {'MLSNumber': 'DENC520832',
#   'Address': '2450 W Eric Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'MAPLECREST',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC518054',
#   'Address': '2413 E Eric Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'MAPLECREST',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Heritage',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'Mckean'},
#  {'MLSNumber': 'DENC507544',
#   'Address': '2402 E Eric Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'MAPLECREST',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC523178',
#   'Address': '2712 Bardell Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'SHERWOOD PARK II',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC522706',
#   'Address': '903 Bradley Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'KIRKWOOD GARDENS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC522466',
#   'Address': '2203 Milltown Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'GRENDON FARMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC503184',
#   'Address': '2438 Owen Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'KIRKWOOD GARDENS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC509278',
#   'Address': '2814 Bexley Ct',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'SKYLINE CREST',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC508528',
#   'Address': '2205 Fenton Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAULKLAND HEIGHTS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC509890',
#   'Address': '2107 Elder Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'ALBERTSON PARK',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC519792',
#   'Address': '2914 Mattahoon Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'ARUNDEL',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC507850',
#   'Address': '2306 Frann Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'TYBROOK',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC501244',
#   'Address': '58 Marta Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'EASTBURN ACRES',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Forest Oak',
#   'Schools-Middle': 'Stanton',
#   'Schools-HighSchool': 'Dickinson'},
#  {'MLSNumber': 'DENC499874',
#   'Address': '11 Cornell Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'COOPER FARMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC523992',
#   'Address': '2509 Lindell Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'GRENDON FARMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Heritage',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'Dickinson'},
#  {'MLSNumber': 'DENC521572',
#   'Address': '2315 Spruce Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'CEDARS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Heritage',
#   'Schools-Middle': 'Skyline',
#   'Schools-HighSchool': 'Mckean'},
#  {'MLSNumber': 'DENC521126',
#   'Address': '132 Attic Ct',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'LIMESTONE HILLS WEST',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC519780',
#   'Address': '4852 Weatherhill Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'WEATHERHILL FARMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC519702',
#   'Address': '2621 Sherwood Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'SHERWOOD PARK I',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC507654',
#   'Address': '3421 Pebble Beach Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'FAIRWAY FALLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC507868',
#   'Address': '1810 School Ln',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'MARSHALLTON HGTS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC506164',
#   'Address': '132 Steven Ln',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'LIMESTONE HILLS',
#   'School_District': 'Red Clay Consolidated',
# ...
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC526442',
#   'Address': '77 Westhampton Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'WESTHAMPTON',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC2019592',
#   'Address': '139 Fairhill Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'LIMESTONE HILLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC522910',
#   'Address': '524 Giada Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'MARRA LANDING',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC2000421',
#   'Address': '722 Ambleside',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'WESTMINSTER',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC2020968',
#   'Address': '166 Fairhill Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'LIMESTONE HILLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'William F. Cooke',
#   'Schools-Middle': 'Henry B. Du Pont',
#   'Schools-HighSchool': 'Thomas Mckean'},
#  {'MLSNumber': 'DENC525382',
#   'Address': '3703 Oak Ridge Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19808,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30903.0,
#   'Subdivision': 'OAKWOOD HILLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Cooke',
#   'Schools-Middle': 'Dupont H',
#   'Schools-HighSchool': 'Mckean'},
#  {'MLSNumber': 'DENC477604',
#   'Address': '106 Wayland Rd',
#   'Category': 'RES',
#   'City': 'Greenville',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'SEDGELY FARMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Brandywine Springs School',
#   'Schools-Middle': 'Henry B. Du Pont',
#   'Schools-HighSchool': 'Alexis I. Dupont'},
#  {'MLSNumber': 'DENC509140',
#   'Address': '115 Bellant Cir',
#   'Category': 'RES',
#   'City': 'Greenville',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'FAIRTHORNE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Brandywine Springs School',
#   'Schools-Middle': 'Alexis I. Du Pont',
#   'Schools-HighSchool': 'Alexis I. Dupont'},
#  {'MLSNumber': 'DENC388762',
#   'Address': '8 Kentshire Ct',
#   'Category': 'RES',
#   'City': 'Greenville',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'STONEWOLD',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Brandywine Springs',
#   'Schools-Middle': 'Alexis I. Du Pont',
#   'Schools-HighSchool': 'Alexis I. Dupont'},
#  {'MLSNumber': 'DENC482626',
#   'Address': '3112 Centerville Rd',
#   'Category': 'RES',
#   'City': 'Greenville',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'SEDGELY FARMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Brandywine Springs',
#   'Schools-Middle': 'Alexis I. Du Pont',
#   'Schools-HighSchool': 'Alexis I. Dupont'},
#  {'MLSNumber': 'DENC500244',
#   'Address': '2 Hedgerow Pl',
#   'Category': 'RES',
#   'City': 'Greenville',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'SEDGELY FARMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC519856',
#   'Address': '15 Gale Ln',
#   'Category': 'RES',
#   'City': 'Greenville',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'FAIRTHORNE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC518580',
#   'Address': '4 Hollingsworth Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'HOLLINGSWORTH',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC506816',
#   'Address': '109 Bellant Cir',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'FAIRTHORNE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC512486',
#   'Address': '3101 Swarthmore Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'WESTMORELAND',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC507478',
#   'Address': '125 Dickinson Ln',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'WEST PARK',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC497414',
#   'Address': '701 Hopeton Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'WESTOVER HILLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC510730',
#   'Address': '4904 Threadneedle Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'SEDGELY FARMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC508534',
#   'Address': '17 Downs Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'LIMERICK',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC478754',
#   'Address': '3901 Heather Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'GREENVILLE MANOR',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': 'Dupont A',
#   'Schools-HighSchool': 'Dupont'},
#  {'MLSNumber': 'DENC504048',
#   'Address': '20 Vining Ln',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'WESTHAVEN',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC495272',
#   'Address': '5803 Pyles Ford Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'NONE AVAILABLE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Brandywine Springs School',
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC482076',
#   'Address': '3 Courtney Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'SEDGELY FARMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC504118',
#   'Address': '106 Quintynnes Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'QUINTYNNES',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC498282',
#   'Address': '5 Aldrich Way',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'WESTHAVEN',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Brandywine Springs',
#   'Schools-Middle': 'Dupont A',
#   'Schools-HighSchool': 'Dupont'},
#  {'MLSNumber': 'DENC500900',
#   'Address': '3 Willing Way',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'WESTHAVEN',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Brandywine Springs',
#   'Schools-Middle': 'Dupont',
#   'Schools-HighSchool': 'Alexis I. Dupont'},
#  {'MLSNumber': 'DENC511416',
#   'Address': '24 Harlech Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'ANGLESEY',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC511946',
#   'Address': '110 Bellant Cir',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'FAIRTHORNE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Brandywine Springs School',
#   'Schools-Middle': 'Dupont A',
#   'Schools-HighSchool': 'Alexis I. Dupont'},
#  {'MLSNumber': 'DENC504558',
#   'Address': '5 Gale Ln',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'FAIRTHORNE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC505130',
#   'Address': '902 Barley Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'BARLEY MILL COURT',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Brandywine Springs',
#   'Schools-Middle': 'Dupont A',
#   'Schools-HighSchool': 'Dupont'},
#  {'MLSNumber': 'DENC504128',
#   'Address': '1005 Oriente Ave',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'FAIRTHORNE',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC517540',
#   'Address': '705 Greenwood Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'WESTOVER HILLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC495262',
#   'Address': '203 N Spring Valley Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'SPRING VALLEY',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC485098',
#   'Address': '11 S Hampshire Ct',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'STONEWOLD',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Brandywine Springs',
#   'Schools-Middle': 'Dupont A',
#   'Schools-HighSchool': 'Dupont'},
#  {'MLSNumber': 'DENC520206',
#   'Address': '2 Harlech Dr',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'ANGLESEY',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC503484',
#   'Address': '720 Greenwood Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'WESTOVER HILLS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC524626',
#   'Address': '17 Vining Ln',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'WESTHAVEN',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC501346',
#   'Address': '3206 Fordham Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'WESTMORELAND',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC489434',
#   'Address': '4919 Lancaster Pike',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'SEDGELY FARMS',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC522326',
#   'Address': '37 Stabler Cir',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'LIMERICK',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC517554',
#   'Address': '212 N Spring Valley Rd',
#   'Category': 'RES',
#   'City': 'Wilmington',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'SPRING VALLEY',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  {'MLSNumber': 'DENC2006324',
#   'Address': '117 Carpenters Row',
#   'Category': 'RES',
#   'City': 'Greenville',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'CARPENTERS ROW',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': 'Brandywine Springs',
#   'Schools-Middle': 'Alexis I. Du Pont',
#   'Schools-HighSchool': 'Alexis I. Dupont'},
#  {'MLSNumber': 'DENC2009668',
#   'Address': '101 Hickory Spring Rd',
#   'Category': 'RES',
#   'City': 'Greenville',
#   'State': 'DE',
#   'Zip_Code': 19807,
#   'County': 'NEWCASTLEDE',
#   'MLSArea': 30902.0,
#   'Subdivision': 'OLD HOBSON FARM',
#   'School_District': 'Red Clay Consolidated',
#   'Schools-Elementary': None,
#   'Schools-Middle': None,
#   'Schools-HighSchool': None},
#  ...]
