# %% [markdown]
# ## Data Extract, Transform, Load

# %%
# If you ever want to reset all your variables, you can use %reset -f by uncommenting and running the next line
#%reset -f

# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %% [markdown]
# ### Clean Public Record Data

# %%
# Read in file 
Pub_Rec_df = pd.read_csv("Resources_raw/Pub_Rec.csv")
#Pub_Rec_df

# %%
# Drop NaN columns and rows
Pub_Rec_df = Pub_Rec_df.dropna(axis=1,how='all').dropna(axis=0,how='all')
#Pub_Rec_df

# %%
# Move foreign key (TaxID) to second column
second_column = Pub_Rec_df.pop("TaxID")
Pub_Rec_df.insert(1,"TaxID", second_column)
#Pub_Rec_df

# %%
# Check data types
Pub_Rec_df.dtypes
# Out:
# MLS Number                   object
# TaxID                        object
# PropertyAddressFormatted     object
# PropertyCityState            object
# Zipcode                       int64
# Zip4                        float64
# CarrierRoute                 object
# PropDoNotMail                object
# OwnerNames                   object
# OwnerLastName                object
# OwnerFirstName               object
# Owner2LastName               object
# Owner2FirstName              object
# Owner3LastName               object
# Owner3FirstName              object
# OwnerAddress                 object
# OwnerCityState               object
# OwnerZipCode                float64
# OwnerZip4                     int64
# OwnerCarrierRoute            object
# OwnerOccupied                  bool
# Municipality                 object
# SubdivisionNeighborhood      object
# TaxIDAlt                     object
# TaxMap                      float64
# Block                        object
# Lot                          object
# SchoolDistrict               object
# TaxYear                       int64
# AnnualTax                     int64
# CountyTax                     int64
# MunicipalTax                  int64
# SchoolTax                     int64
# TotalLandAsmt                 int64
# TotalBldgAsmt                 int64
# TaxableTotalAsmt              int64
# DeedRecordDate               object
# SettleDate                   object
# SaleAmt                       int64
# SaleType                     object
# PropertyClass                object
# CondoYN                      object
# LotFrontage                 float64
# LotDepth                    float64
# LotSqFt                       int64
# LotAcres                    float64
# LotShape                     object
# Zoning                       object
# BldgSqFtTotal               float64
# Stories                     float64
# Bedrooms                    float64
# Exterior                     object
# BsmtDesc                     object
# FireplaceTotal              float64
# GrgType                      object
# HeatDelivery                 object
# YearBuilt                   float64
# YearRemod                   float64
# dtype: object

# %%
# Convert data types, rename columns and reformat as needed, 
Pub_Rec_df.rename(columns = {'MLS Number':'MLSNumber'}, inplace=True)
Pub_Rec_df.rename(columns = {'PropertyAddressFormatted':'Address-truncated'}, inplace=True)
Pub_Rec_df.rename(columns = {'TaxID':'Tax_ID'}, inplace=True)
Pub_Rec_df['Zipcode'] = Pub_Rec_df['Zipcode'].astype(str)
Pub_Rec_df.rename(columns = {'Zipcode':'Zip_Code'}, inplace=True)
Pub_Rec_df["Zip4"] = Pub_Rec_df["Zip4"].map("{:.0f}".format)
Pub_Rec_df['Zip4'] = Pub_Rec_df['Zip4'].astype(str)
Pub_Rec_df['OwnerZipCode'] = Pub_Rec_df['OwnerZipCode'].astype(str)
Pub_Rec_df['OwnerZip4'] = Pub_Rec_df['OwnerZip4'].astype(str)
Pub_Rec_df['TaxMap'] = Pub_Rec_df['TaxMap'].astype(str)
Pub_Rec_df["DeedRecordDate"] =  pd.to_datetime(Pub_Rec_df["DeedRecordDate"], format="%m/%d/%y")
Pub_Rec_df["SettleDate"] =  pd.to_datetime(Pub_Rec_df["SettleDate"], format="%m/%d/%y")
Pub_Rec_df["YearBuilt"] = Pub_Rec_df["YearBuilt"].map("{:.0f}".format)
Pub_Rec_df["YearRemod"] = Pub_Rec_df["YearRemod"].map("{:.0f}".format)
Pub_Rec_df.dtypes
# Out:
# MLSNumber                          object
# Tax_ID                             object
# Address-truncated                  object
# PropertyCityState                  object
# Zip_Code                           object
# Zip4                               object
# CarrierRoute                       object
# PropDoNotMail                      object
# OwnerNames                         object
# OwnerLastName                      object
# OwnerFirstName                     object
# Owner2LastName                     object
# Owner2FirstName                    object
# Owner3LastName                     object
# Owner3FirstName                    object
# OwnerAddress                       object
# OwnerCityState                     object
# OwnerZipCode                       object
# OwnerZip4                          object
# OwnerCarrierRoute                  object
# OwnerOccupied                        bool
# Municipality                       object
# SubdivisionNeighborhood            object
# TaxIDAlt                           object
# TaxMap                             object
# Block                              object
# Lot                                object
# SchoolDistrict                     object
# TaxYear                             int64
# AnnualTax                           int64
# CountyTax                           int64
# MunicipalTax                        int64
# SchoolTax                           int64
# TotalLandAsmt                       int64
# TotalBldgAsmt                       int64
# TaxableTotalAsmt                    int64
# DeedRecordDate             datetime64[ns]
# SettleDate                 datetime64[ns]
# SaleAmt                             int64
# SaleType                           object
# PropertyClass                      object
# CondoYN                            object
# LotFrontage                       float64
# LotDepth                          float64
# LotSqFt                             int64
# LotAcres                          float64
# LotShape                           object
# Zoning                             object
# BldgSqFtTotal                     float64
# Stories                           float64
# Bedrooms                          float64
# Exterior                           object
# BsmtDesc                           object
# FireplaceTotal                    float64
# GrgType                            object
# HeatDelivery                       object
# YearBuilt                          object
# YearRemod                          object
# dtype: object

# %%
# Show clean dataframe
Pub_Rec_df
# Out:
#         MLSNumber         Tax_ID       Address-truncated PropertyCityState  \
# 0      DENC518086  08-038.30-119         2615 Pecksniff     Wilmington, DE
# 1      DENC518982  08-036.10-081          4938 S Tupelo     Wilmington, DE
# 2      DENC512992  08-044.30-363            15 Kristina     Wilmington, DE
# 3      DENC512104  08-036.40-376         3251 Champions     Wilmington, DE
# 4      DENC503480  07-041.10-071         3706 Lafayette     Wilmington, DE
# ...           ...            ...                     ...               ...
# 5571   DENC520114  08-020.40-046            101 Meriden      Hockessin, DE
# 5572   DENC520392  07-010.00-054    417 Snuff Mill Hill      Hockessin, DE
# 5573  DENC2014038  08-012.10-027             400 Wilson      Hockessin, DE
# 5574  DENC2005484  08-004.30-016         918 Old Public      Hockessin, DE
# 5575   DENC526982  08-024.40-266  124 Croom Mills Drive      Hockessin, DE
#
#      Zip_Code  Zip4 CarrierRoute PropDoNotMail  \
# 0       19808  3026         C010             N
# 1       19808  1026         C009             N
# 2       19808  4063         C084             N
# 3       19808  2601         C039             N
# 4       19808  6014         C001             N
# ...       ...   ...          ...           ...
# 5571    19707  1704         R004             N
# 5572    19707  9638         R002             N
# 5573    19707  9207         R001             N
# 5574    19707  9679         R011             N
# 5575    19707  8924         R013             N
#
#                                    OwnerNames OwnerLastName  ...  \
# 0                              James Robinson      Robinson  ...
# 1                               Xiaopeng Deng          Deng  ...
# 2                              Robert F Walls         Walls  ...
# 3                             Michael J Downs         Downs  ...
# 4                                Maria Corona        Corona  ...
# ...                                       ...           ...  ...
# 5571                  Michael J N Generations   Generations  ...
# 5572  Jacqueline G Truluck & Breck L Robinson       Truluck  ...
# 5573                           Kevin K Thomas        Thomas  ...
# 5574                        Lawrence P Murphy        Murphy  ...
# 5575                Lee S & Dorel K Peplinski     Peplinski  ...
#
#      BldgSqFtTotal Stories Bedrooms                     Exterior  BsmtDesc  \
# 0           1875.0     1.0      3.0       Brick, Aluminum, Vinyl  Finished
# 1           1575.0     2.0      3.0       Brick, Aluminum, Vinyl  Finished
# 2              NaN     2.0      2.0              Aluminum, Vinyl       NaN
# 3              NaN     2.0      2.0                        Other       NaN
# 4              NaN     1.0      3.0                     Asbestos       NaN
# ...            ...     ...      ...                          ...       ...
# 5571        2925.0     1.0      3.0  Frame, Siding - Wood, Stone       NaN
# 5572        3700.0     2.0      4.0         Siding - Wood, Frame  Finished
# 5573        2850.0     2.0      4.0       Brick, Aluminum, Vinyl  Finished
# 5574           NaN     2.0      4.0       Aluminum, Vinyl, Brick       NaN
# 5575           NaN     2.0      2.0       Vinyl, Brick, Aluminum       NaN
#
#      FireplaceTotal           GrgType     HeatDelivery YearBuilt YearRemod
# 0               0.0  Att/BuiltIn/Bsmt  Hot Water/Steam      1958         0
# 1               0.0               NaN     Hot/Warm Air      1976         0
# 2               0.0               NaN        Heat Pump      1985         0
# 3               1.0  Att/BuiltIn/Bsmt        Heat Pump      1985         0
# 4               0.0               NaN     Hot/Warm Air      1957         0
# ...             ...               ...              ...       ...       ...
# 5571            1.0               NaN     Hot/Warm Air      1958         0
# 5572            2.0  Att/BuiltIn/Bsmt        Heat Pump      1973         0
# 5573            1.0  Att/BuiltIn/Bsmt     Hot/Warm Air      1989         0
# 5574            1.0  Att/BuiltIn/Bsmt     Hot/Warm Air      1992         0
# 5575            0.0  Att/BuiltIn/Bsmt     Hot/Warm Air      2002         0
#
# [5576 rows x 58 columns]

# %% [markdown]
# ### Clean Broker Data

# %%
# Read in file
broker_df = pd.read_csv("Resources_raw/Broker_Data.csv")
#broker_df.head()

# %%
# Drop unnecssary columns and NaN rows and columns: show clean dataframe
broker_df = broker_df.drop(columns=['ListOfficePhone','ListAgentPhone','ListAgentEmail','AgentRemarks','Showing Instructions'])\
    .dropna(axis=1,how='all').dropna(axis=0,how='all')
broker_df
# Out:
#         MLSNumber                 Address                   ListOfficeName  \
# 0      DENC518086       2615 Pecksniff Rd    Patterson-Schwartz-Middletown
# 1      DENC518982      4938 S Tupelo Turn  Long & Foster Real Estate, Inc.
# 2      DENC512992          15 Kristina Ct  Long & Foster Real Estate, Inc.
# 3      DENC512104       3251 Champions Dr  Long & Foster Real Estate, Inc.
# 4      DENC503480       3706 Lafayette St             Meyer & Meyer Realty
# ...           ...                     ...                              ...
# 5571   DENC520114          101 Meriden Dr      BHHS Fox & Roach-Kennett Sq
# 5572   DENC520392  417 Snuff Mill Hill Rd      BHHS Fox & Roach-Greenville
# 5573  DENC2014038           400 Wilson Ct     BHHS Fox & Roach - Hockessin
# 5574  DENC2005484       918 Old Public Rd                  EXP Realty, LLC
# 5575   DENC526982   124 Croom Mills Drive     Patterson-Schwartz-Hockessin
#
#                 ListAgentName
# 0                Dianne Platt
# 1                Andrew White
# 2          Diane W Bacigalupi
# 3           Barbara Carpenter
# 4               Peggy Cushing
# ...                       ...
# 5571      Joelle C Waterkotte
# 5572       Sharon Satterfield
# 5573           Jeff Bollinger
# 5574   Andrew Joseph Szczerba
# 5575  Melanie J Kent-Richmond
#
# [5576 rows x 4 columns]

# %%
broker_df.dtypes
# Out:
# MLSNumber         object
# Address           object
# ListOfficeName    object
# ListAgentName     object
# dtype: object

# %% [markdown]
# ### Clean ID_Table

# %%
# Read in file
ID_table_df = pd.read_csv("Resources_raw/ID_table.csv")
#ID_table_df

# %%
# Delete unnessary columns and drop NaN rows and columns, reformat as needed
ID_table_df = ID_table_df.drop(columns=['Township','OriginatingMLS ','CrossStreet', 'FloorNumber','Ownership','Senior Community YN','Condo/Coop Assoc YN','HOA YN','AssociationFee','AssociationFeeFrequency','Structure Type ','StreetNumber','StreetName','UnitNumber'])\
     .dropna(axis=1,how='all').dropna(axis=0,how='all')
ID_table_df["Zip Code"] = ID_table_df["Zip Code"].map("{:.0f}".format)
ID_table_df.rename(columns = {'Zip Code':'Zip_Code'}, inplace=True)
ID_table_df.rename(columns = {'School District':'School_District'}, inplace=True)
#ID_table_df

# %%
# Check data types
#ID_table_df.dtypes

# %%
# Convert data types as needed
ID_table_df['Zip_Code'] = ID_table_df['Zip_Code'].astype(str)
ID_table_df['MLSArea'] = ID_table_df['MLSArea'].astype(str)
ID_table_df.dtypes
# Out:
# MLSNumber             object
# Address               object
# Category              object
# City                  object
# State                 object
# Zip_Code              object
# County                object
# MLSArea               object
# Subdivision           object
# School_District       object
# Schools-Elementary    object
# Schools-Middle        object
# Schools-HighSchool    object
# dtype: object

# %%
# Show clean datframe
ID_table_df
# Out:
#         MLSNumber                 Address Category        City State Zip_Code  \
# 0      DENC518086       2615 Pecksniff Rd      RES   Wilmingon    DE    19808
# 1      DENC518982      4938 S Tupelo Turn      RES  Wilmington    DE    19808
# 2      DENC512992          15 Kristina Ct      RES  Wilmington    DE    19808
# 3      DENC512104       3251 Champions Dr      RES  Wilmington    DE    19808
# 4      DENC503480       3706 Lafayette St      RES  Wilmington    DE    19808
# ...           ...                     ...      ...         ...   ...      ...
# 5571   DENC520114          101 Meriden Dr      RES   Hockessin    DE    19707
# 5572   DENC520392  417 Snuff Mill Hill Rd      RES   Hockessin    DE    19707
# 5573  DENC2014038           400 Wilson Ct      RES   Hockessin    DE    19707
# 5574  DENC2005484       918 Old Public Rd      RES   Hockessin    DE    19707
# 5575   DENC526982   124 Croom Mills Drive      RES  Wilmington    DE    19707
#
#            County  MLSArea         Subdivision        School_District  \
# 0     NEWCASTLEDE  30903.0    SHERWOOD PARK II  Red Clay Consolidated
# 1     NEWCASTLEDE  30903.0        PEPPER RIDGE  Red Clay Consolidated
# 2     NEWCASTLEDE  30903.0            WOODMILL  Red Clay Consolidated
# 3     NEWCASTLEDE  30903.0       FAIRWAY FALLS  Red Clay Consolidated
# 4     NEWCASTLEDE  30903.0  WASHINGTON HEIGHTS  Red Clay Consolidated
# ...           ...      ...                 ...                    ...
# 5571  NEWCASTLEDE  30902.0    CANTERBURY HILLS  Red Clay Consolidated
# 5572  NEWCASTLEDE  30902.0          SNUFF MILL  Red Clay Consolidated
# 5573  NEWCASTLEDE  30902.0      STENNING WOODS  Red Clay Consolidated
# 5574  NEWCASTLEDE  30902.0     QUAKER LEA EAST  Red Clay Consolidated
# 5575  NEWCASTLEDE  30903.0       ADARE VILLAGE  Red Clay Consolidated
#
#       Schools-Elementary    Schools-Middle Schools-HighSchool
# 0                    NaN               NaN                NaN
# 1                    NaN               NaN                NaN
# 2                    NaN               NaN                NaN
# 3                    NaN               NaN                NaN
# 4                    NaN               NaN                NaN
# ...                  ...               ...                ...
# 5571                 NaN               NaN                NaN
# 5572  Brandywine Springs  Henry B. Du Pont   Alexis I. Dupont
# 5573          North Star  Henry B. Du Pont   Alexis I. Dupont
# 5574                 NaN               NaN                NaN
# 5575                 NaN               NaN                NaN
#
# [5576 rows x 13 columns]

# %% [markdown]
# ### Clean Mortgage_Data

# %%
Mortgage_Data_df = pd.read_csv("Resources_raw/Mortgage_Data.csv")
#Mortgage_Data_df

# %%
Mortgage_Data_df = Mortgage_Data_df.dropna(axis=1,how='all').dropna(axis=0,how='all')
#Mortgage_Data_df

# %%
Mortgage_Data_df.rename(columns = {'Tax ID':'Tax_ID'}, inplace=True)

# %%
# Convert data types, rename columns and reformat as needed, 
Mortgage_Data_df.rename(columns = {'Tax ID':'Tax_ID'}, inplace=True)
Mortgage_Data_df.rename(columns = {'Mort Amt':'Mort_Amt'}, inplace=True)
Mortgage_Data_df.rename(columns = {'Mortgage Type':'Mort_Type'}, inplace=True)
Mortgage_Data_df.rename(columns = {'Mort Int Rate':'Mort_Int_Rate'}, inplace=True)
Mortgage_Data_df.rename(columns = {'Mort Term':'Mort_Term'}, inplace=True)
Mortgage_Data_df.rename(columns = {'Mort Record Date':'Mort_Record_Date'}, inplace=True)
Mortgage_Data_df.rename(columns = {'Mort Due Date':'Mort_Due_Date'}, inplace=True)
Mortgage_Data_df.rename(columns = {'Mort Date':'Mort_Date'}, inplace=True)

# %%
# Check data types
Mortgage_Data_df.dtypes
# Out:
# Tax_ID               object
# Address              object
# Lender               object
# Mort_Amt            float64
# Mort_Type            object
# Mort_Int_Rate       float64
# Mort_Term            object
# Mort_Record_Date     object
# Mort_Due_Date        object
# Mort_Date            object
# dtype: object

# %%
# Show clean datframe
Mortgage_Data_df
# Out:
#                    Tax_ID                             Address  \
# 0     06-004.00-004.C.010          108 N Landis Way Unit #108
# 1     06-004.00-004.C.014        140 N Landis Way N Unit #140
# 2     06-004.00-004.C.021        216 S Landis Way S Unit #216
# 3     06-004.00-004.C.033            339 Cassell Ct Unit #339
# 4     06-004.00-004.C.034            346 Cassell Ct Unit #346
# ...                   ...                                 ...
# 2112  26-050.10-068.C.200  105-UNIT Christina Landing Dr Unit
# 2113  26-050.10-068.C.240  105-UNIT Christina Landing Dr Unit
# 2114  26-050.10-068.C.250  105-UNIT Christina Landing Dr Unit
# 2115        26-051.30-160                       1215 Apple St
# 2116        26-058.10-174                   448 S Claymont St
#
#                                                  Lender  Mort_Amt  \
# 0     AMERICAN NBRHD MTG ACCPTNC AMERICAN NBRHD MTG ...  388000.0
# 1                                     WSFS MTG WSFS MTG  420000.0
# 2                                              WSFS MTG  220000.0
# 3                                       RBS CITIZENS NA  165000.0
# 4                   TRIDENT MTG CO LP TRIDENT MTG CO LP  297500.0
# ...                                                 ...       ...
# 2112                HUNTINGDON VLY BK HUNTINGDON VLY BK  244250.0
# 2113        PROSPERITY HM MTG LLC PROSPERITY HM MTG LLC  310000.0
# 2114                                  NAVY FCU NAVY FCU  473500.0
# 2115                BROADVIEW CAP LLC BROADVIEW CAP LLC  492000.0
# 2116                                DOVER FCU DOVER FCU  200000.0
#
#                           Mort_Type  Mort_Int_Rate Mort_Term Mort_Record_Date  \
# 0               Conv,HomeEquityLoan            0.0        15          3/16/22
# 1               Conv,HomeEquityLoan            0.0        30          8/24/21
# 2                              Conv            0.0        30         11/15/16
# 3               Conv,HomeEquityLoan            0.0        25         10/17/14
# 4                              Conv            0.0        15           1/7/21
# ...                             ...            ...       ...              ...
# 2112                 Conv,Refinance            0.0        15          5/11/20
# 2113                           Conv            0.0        15           5/5/22
# 2114                           Conv            0.0        30           3/4/21
# 2115  BlanketMortgage,ConstructionL            0.0         1          1/20/22
# 2116    BlanketMortgage,Conv,HomeEq            0.0        10           6/3/22
#
#      Mort_Due_Date Mort_Date
# 0           4/1/37   3/11/22
# 1           9/1/51   8/17/21
# 2          12/1/46  11/10/16
# 3         10/10/39   10/6/14
# 4           1/1/36   12/8/20
# ...            ...       ...
# 2112        6/1/35   4/30/20
# 2113        6/1/37    5/3/22
# 2114        3/1/51   2/26/21
# 2115        1/1/23  12/22/21
# 2116       5/11/32   5/11/22
#
# [2117 rows x 10 columns]

# %% [markdown]
# ### Clean Sales_Data

# %%
# Read in file
Sales_Data_df = pd.read_csv("Resources_raw/Sales_Data.csv")
#Sales_Data_df

# %%
# Drop NaN columns and rows
Sales_Data_df = Sales_Data_df.dropna(axis=1,how='all').dropna(axis=0,how='all')
#Sales_Data_df

# %%
# Check data types
#Sales_Data_df.dtypes

# %%
# Convert data types, rename columns and reformat as needed, 
Sales_Data_df["ListDate"] =  pd.to_datetime(Sales_Data_df["ListDate"], format="%m/%d/%y")
Sales_Data_df["StatusDate"] =  pd.to_datetime(Sales_Data_df["StatusDate"], format="%m/%d/%y")
Sales_Data_df["Agreement of Sale/Signed Lease Date"] =  pd.to_datetime(Sales_Data_df["Agreement of Sale/Signed Lease Date"], format="%m/%d/%y")
Sales_Data_df["SettledDate"] =  pd.to_datetime(Sales_Data_df["SettledDate"], format="%m/%d/%y")
Sales_Data_df.rename(columns = {'Sold Price':'Sold_Price'}, inplace=True)
Sales_Data_df.rename(columns = {'Sold Price less Concession':'Sold_Price_less_Concession'}, inplace=True)
Sales_Data_df.rename(columns = {'Orig List Price':'Orig_List_Price'}, inplace=True)
Sales_Data_df.rename(columns = {'Current List Price':'Current_List_Price'}, inplace=True)
Sales_Data_df.rename(columns = {'Days on Market':'Days_on_Market'}, inplace=True)
Sales_Data_df.rename(columns = {'Previous Days on Market':'Previous_Days_on_Market'}, inplace=True)
Sales_Data_df.rename(columns = {'Agreement of Sale/Signed Lease Date':'Agreement_of_Sale_Date'}, inplace=True)
Sales_Data_df.rename(columns = {'Concessions YN':'Concessions_YN'}, inplace=True)
Sales_Data_df.rename(columns = {'Concessions Remarks':'Concessions_Remarks'}, inplace=True)
Sales_Data_df.dtypes
# Out:
# MLSNumber                             object
# Address                               object
# Status                                object
# Sold_Price                           float64
# Sold_Price_less_Concession           float64
# Orig_List_Price                      float64
# Current_List_Price                   float64
# Days_on_Market                       float64
# Previous_Days_on_Market              float64
# ListDate                      datetime64[ns]
# StatusDate                    datetime64[ns]
# Agreement_of_Sale_Date        datetime64[ns]
# SettledDate                   datetime64[ns]
# Concessions_YN                        object
# Concessions_Remarks                   object
# SellerConcessionsAmount              float64
# FinalFinancing                        object
# dtype: object

# %%
# Show clean datframe
Sales_Data_df
# Out:
#         MLSNumber                 Address  Status  Sold_Price  \
# 0      DENC518086       2615 Pecksniff Rd  Closed    335000.0
# 1      DENC518982      4938 S Tupelo Turn  Closed    200000.0
# 2      DENC512992          15 Kristina Ct  Closed    200000.0
# 3      DENC512104       3251 Champions Dr  Closed    200000.0
# 4      DENC503480       3706 Lafayette St  Closed    200000.0
# ...           ...                     ...     ...         ...
# 5571   DENC520114          101 Meriden Dr  Closed    595000.0
# 5572   DENC520392  417 Snuff Mill Hill Rd  Closed    595000.0
# 5573  DENC2014038           400 Wilson Ct  Closed    600000.0
# 5574  DENC2005484       918 Old Public Rd  Closed    600000.0
# 5575   DENC526982   124 Croom Mills Drive  Closed    350000.0
#
#       Sold_Price_less_Concession  Orig_List_Price  Current_List_Price  \
# 0                       335000.0         330000.0            330000.0
# 1                       200000.0         215500.0            210000.0
# 2                       200000.0         200000.0            200000.0
# 3                       200000.0         219900.0            214900.0
# 4                       200000.0         190000.0            190000.0
# ...                          ...              ...                 ...
# 5571                    595000.0         595000.0            595000.0
# 5572                    591262.0         639000.0            639000.0
# 5573                    600000.0         529900.0            529900.0
# 5574                    598000.0         620000.0            620000.0
# 5575                    349000.0         350000.0            350000.0
#
#       Days_on_Market  Previous_Days_on_Market   ListDate StatusDate  \
# 0                5.0                      5.0 2020-12-11 2021-02-11
# 1               47.0                     67.0 2021-01-07 2021-04-08
# 2               15.0                     15.0 2020-12-28 2021-02-26
# 3               11.0                     11.0 2020-10-27 2020-12-14
# 4                3.0                      3.0 2020-06-20 2020-08-02
# ...              ...                      ...        ...        ...
# 5571             5.0                      5.0 2021-06-24 2021-07-28
# 5572            25.0                     25.0 2021-03-29 2021-06-10
# 5573             7.0                      7.0 2022-01-14 2022-03-04
# 5574            25.0                     25.0 2021-08-26 2021-10-27
# 5575            51.0                     51.0 2021-05-19 2021-07-30
#
#      Agreement_of_Sale_Date SettledDate Concessions_YN Concessions_Remarks  \
# 0                2020-12-16  2021-02-11             No                 NaN
# 1                2021-02-21  2021-04-08             No                 NaN
# 2                2021-01-09  2021-02-26             No                 NaN
# 3                2020-11-05  2020-12-11             No                 NaN
# 4                2020-06-21  2020-07-31             No                 NaN
# ...                     ...         ...            ...                 ...
# 5571             2021-06-28  2021-07-28             No                 NaN
# 5572             2021-04-21  2021-06-10            Yes                 NaN
# 5573             2022-01-19  2022-03-04             No                 NaN
# 5574             2021-09-18  2021-10-26            Yes  Inspections credit
# 5575             2021-07-07  2021-07-30            Yes                 NaN
#
#       SellerConcessionsAmount FinalFinancing
# 0                         0.0            FHA
# 1                         0.0   Conventional
# 2                         0.0   Conventional
# 3                         0.0   Conventional
# 4                         0.0   Conventional
# ...                       ...            ...
# 5571                      0.0           Cash
# 5572                   3738.0   Conventional
# 5573                      0.0   Conventional
# 5574                   2000.0   Conventional
# 5575                   1000.0           Cash
#
# [5576 rows x 17 columns]

# %% [markdown]
# ### Clean Public Remarks

# %%
# Read in file
Pub_Remarks_df = pd.read_csv("Resources_raw/Pub_Remarks.csv")
Pub_Remarks_df
# Out:
#         MLSNumber                 Address  \
# 0      DENC518086       2615 Pecksniff Rd
# 1      DENC518982      4938 S Tupelo Turn
# 2      DENC512992          15 Kristina Ct
# 3      DENC512104       3251 Champions Dr
# 4      DENC503480       3706 Lafayette St
# ...           ...                     ...
# 5571   DENC520114          101 Meriden Dr
# 5572   DENC520392  417 Snuff Mill Hill Rd
# 5573  DENC2014038           400 Wilson Ct
# 5574  DENC2005484       918 Old Public Rd
# 5575   DENC526982   124 Croom Mills Drive
#
#                                           PublicRemarks
# 0     Visit this home virtually: http://www.vht.com/...
# 1     3 bedroom, 1.5 bath townhome located in the he...
# 2     Location, Location, Location! This Woodmill to...
# 3     Move right into this 2 bedroom, 2.1 bath townh...
# 4     This nicely maintained home is being sold to s...
# ...                                                 ...
# 5571  Welcome to 101 Meriden Drive! This sleek, upda...
# 5572  When asked what they loved about their home, t...
# 5573  Impeccably maintained cul-de-sac property in t...
# 5574  Impeccably maintained, custom built Colonial w...
# 5575  ***Back on the market after extensive painting...
#
# [5576 rows x 3 columns]

# %%
Pub_Remarks_df.dtypes
# Out:
# MLSNumber        object
# Address          object
# PublicRemarks    object
# dtype: object

# %% [markdown]
# ### Clean Property Characteristics

# %%
# Read in file
Prop_Charac_df = pd.read_csv("Resources_raw/Prop_Charac.csv")
#Prop_Charac_df

# %%
# Drop NaN columns and rows, rename as needed
Prop_Charac_df = Prop_Charac_df.dropna(axis=1,how='all').dropna(axis=0,how='all')
Prop_Charac_df.rename(columns = {'Senior Community YN':'Senior_Community_YN'}, inplace=True)
Prop_Charac_df.rename(columns = {'Condo/Coop Assoc YN':'Condo/Coop_Assoc_YN'}, inplace=True)
Prop_Charac_df.rename(columns = {'HOA YN':'HOA_YN'}, inplace=True)
Prop_Charac_df.rename(columns = {'Structure Type ':'Structure_Type'}, inplace=True)
Prop_Charac_df.rename(columns = {'Interior SqFt Source':'Interior_SqFt_Source'}, inplace=True)
Prop_Charac_df.rename(columns = {'Central Air YN':'Central_Air_YN'}, inplace=True)
Prop_Charac_df.rename(columns = {'Fireplace YN':'Fireplace_YN'}, inplace=True)
Prop_Charac_df.rename(columns = {'Basement YN':'Basement_YN'}, inplace=True)
Prop_Charac_df.rename(columns = {'Garage YN':'Garage_YN'}, inplace=True)
Prop_Charac_df.rename(columns = {'Main Roof':'Main_Roof'}, inplace=True)
#Prop_Charac_df

# %%
# Check data types
Prop_Charac_df.dtypes
# Out:
# MLSNumber                     object
# Address                       object
# BuildingName                  object
# Ownership                     object
# Senior_Community_YN           object
# Condo/Coop_Assoc_YN           object
# HOA_YN                        object
# AssociationFee                object
# AssociationFeeFrequency       object
# Structure_Type                object
# Acres                        float64
# LotDimensions                 object
# LotDescription                object
# FeeIncludes                   object
# Age                          float64
# InteriorSqFt                 float64
# Interior_SqFt_Source          object
# AboveGradeSqFt               float64
# BelowGradeSqFt               float64
# PropertyCondition             object
# Bedrooms                     float64
# Baths                        float64
# BathsFull                    float64
# PartialBaths                 float64
# Design                        object
# Style                         object
# NumberofStories               object
# RoomCount                    float64
# InteriorFeatures              object
# Flooring                      object
# Central_Air_YN                object
# Cooling                       object
# PrimaryHeat                   object
# HeatDelivery                  object
# HotWater                      object
# ElectricalSystem              object
# Water                         object
# Sewer                         object
# Fireplace_YN                  object
# FireplaceCount               float64
# FireplaceFeatures             object
# KitchenAppliancesFeatures     object
# CookingFuel                   object
# LaundryHookUps                object
# Basement_YN                   object
# BasementType                  object
# BasementDescription           object
# BasementFootprintPct         float64
# BasementFinishedPct          float64
# Garage_YN                     object
# GarageSpaces                 float64
# GarageFeatures                object
# Parking                       object
# ExteriorFeatures              object
# ExteriorMaterial              object
# Main_Roof                     object
# Foundation                    object
# PorchDeck                     object
# SwimmingPoolType              object
# dtype: object

# %%
# Show clean datframe
Prop_Charac_df
# Out:
#         MLSNumber                 Address    BuildingName  Ownership  \
# 0      DENC518086       2615 Pecksniff Rd  NONE AVAILABLE  FeeSimple
# 1      DENC518982      4938 S Tupelo Turn             NaN  FeeSimple
# 2      DENC512992          15 Kristina Ct             NaN  FeeSimple
# 3      DENC512104       3251 Champions Dr             NaN  FeeSimple
# 4      DENC503480       3706 Lafayette St             NaN  FeeSimple
# ...           ...                     ...             ...        ...
# 5571   DENC520114          101 Meriden Dr             NaN  FeeSimple
# 5572   DENC520392  417 Snuff Mill Hill Rd             NaN  FeeSimple
# 5573  DENC2014038           400 Wilson Ct             NaN  FeeSimple
# 5574  DENC2005484       918 Old Public Rd             NaN  FeeSimple
# 5575   DENC526982   124 Croom Mills Drive  NONE AVAILABLE  FeeSimple
#
#      Senior_Community_YN Condo/Coop_Assoc_YN HOA_YN AssociationFee  \
# 0                     No                  No    Yes           $15
# 1                     No                  No     No            NaN
# 2                     No                  No     No            NaN
# 3                     No                  No    Yes           $50
# 4                     No                  No     No            NaN
# ...                  ...                 ...    ...            ...
# 5571                  No                  No    Yes          $500
# 5572                  No                  No    Yes              $
# 5573                  No                  No     No            NaN
# 5574                  No                  No     No            NaN
# 5575                 Yes                  No    Yes          $195
#
#      AssociationFeeFrequency          Structure_Type  ...  Garage_YN  \
# 0                   Annually                Detached  ...        Yes
# 1                        NaN  Interior Row/Townhouse  ...         No
# 2                        NaN  Interior Row/Townhouse  ...         No
# 3                   Annually  Interior Row/Townhouse  ...        Yes
# 4                        NaN                Detached  ...         No
# ...                      ...                     ...  ...        ...
# 5571                Annually                Detached  ...        Yes
# 5572                 Unknown                Detached  ...        Yes
# 5573                     NaN                Detached  ...        Yes
# 5574                     NaN                Detached  ...        Yes
# 5575                 Monthly  Interior Row/Townhouse  ...        Yes
#
#      GarageSpaces   GarageFeatures          Parking  \
# 0             1.0              NaN              NaN
# 1             NaN              NaN              NaN
# 2             NaN              NaN              NaN
# 3             1.0              NaN              NaN
# 4             NaN              NaN              NaN
# ...           ...              ...              ...
# 5571          2.0  AsphaltDriveway  AsphaltDriveway
# 5572          2.0              NaN              NaN
# 5573          2.0              NaN              NaN
# 5574          2.0              NaN              NaN
# 5575          1.0              NaN              NaN
#
#                                        ExteriorFeatures  \
# 0     ExtensiveHardscape,Sidewalks,StoneRetainingWal...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5571             ExtensiveHardscape,StoneRetainingWalls
# 5572  ExtensiveHardscape,ExteriorLighting,FloodLight...
# 5573                                                NaN
# 5574             Awnings,ExteriorLighting,LawnSprinkler
# 5575                                       StreetLights
#
#                            ExteriorMaterial             Main_Roof  \
# 0                    BrickFront,VinylSiding  ArchitecturalShingle
# 1          AluminumSiding,Brick,VinylSiding               Asphalt
# 2                               VinylSiding                   NaN
# 3                                     Other               Shingle
# 4                                  Asbestos                   NaN
# ...                                     ...                   ...
# 5571                      Stone,VinylSiding       Pitched,Shingle
# 5572  Cedar,Combination,Mixed,MixedPlumbing    Flat,Shake,Shingle
# 5573       AluminumSiding,Brick,VinylSiding                   NaN
# 5574                                  Brick                   NaN
# 5575                      Brick,VinylSiding                   NaN
#
#              Foundation                          PorchDeck SwimmingPoolType
# 0                   NaN                     Patios,Porches              NaN
# 1                   NaN                                NaN              NaN
# 2                   NaN                                NaN              NaN
# 3                   NaN                             Patios              NaN
# 4                   NaN                                NaN              NaN
# ...                 ...                                ...              ...
# 5571                NaN               Brick,Patios,Porches              NaN
# 5572                NaN  Decks,Porches,Screened,WrapAround              NaN
# 5573  ConcretePerimeter                                NaN              NaN
# 5574                NaN                              Decks              NaN
# 5575                NaN                                NaN              NaN
#
# [5576 rows x 59 columns]

# %% [markdown]
# ### Clean Lat_Lng Data

# %%
# Read in file
lat_lng_df = pd.read_csv("Resources_raw/lat_lng_full.csv")
lat_lng_df
# Out:
#        MLS Number                           address_new        lat        lng
# 0      DENC518086        2615 Pecksniff  Wilmington, DE  39.734608 -75.661402
# 1      DENC518086        2615 Pecksniff  Wilmington, DE  39.734608 -75.661402
# 2     DENC2018974        2615 Pecksniff  Wilmington, DE  39.734608 -75.661402
# 3     DENC2018974        2615 Pecksniff  Wilmington, DE  39.734608 -75.661402
# 4      DENC518982         4938 S Tupelo  Wilmington, DE  39.744655 -75.548391
# ...           ...                                   ...        ...        ...
# 5745   DENC520114            101 Meriden  Hockessin, DE  39.763823 -75.652016
# 5746   DENC520392    417 Snuff Mill Hill  Hockessin, DE  39.809390 -75.667333
# 5747  DENC2014038             400 Wilson  Hockessin, DE  39.780478 -75.717182
# 5748  DENC2005484         918 Old Public  Hockessin, DE  39.795708 -75.688011
# 5749   DENC526982  124 Croom Mills Drive  Hockessin, DE  39.755896 -75.704279
#
# [5750 rows x 4 columns]

# %%
# Drop Duplicates
#lat_lng_df.sort_values("MLS Number", inplace=True)
lat_lng_df.drop_duplicates("MLS Number", keep="first", inplace=True)
lat_lng_df.rename(columns = {'MLS Number':'MLSNumber'}, inplace=True)
lat_lng_df
# Out:
#         MLSNumber                           address_new        lat        lng
# 0      DENC518086        2615 Pecksniff  Wilmington, DE  39.734608 -75.661402
# 2     DENC2018974        2615 Pecksniff  Wilmington, DE  39.734608 -75.661402
# 4      DENC518982         4938 S Tupelo  Wilmington, DE  39.744655 -75.548391
# 5      DENC512992           15 Kristina  Wilmington, DE  39.744655 -75.548391
# 6      DENC512104        3251 Champions  Wilmington, DE  39.729664 -75.698656
# ...           ...                                   ...        ...        ...
# 5745   DENC520114            101 Meriden  Hockessin, DE  39.763823 -75.652016
# 5746   DENC520392    417 Snuff Mill Hill  Hockessin, DE  39.809390 -75.667333
# 5747  DENC2014038             400 Wilson  Hockessin, DE  39.780478 -75.717182
# 5748  DENC2005484         918 Old Public  Hockessin, DE  39.795708 -75.688011
# 5749   DENC526982  124 Croom Mills Drive  Hockessin, DE  39.755896 -75.704279
#
# [5576 rows x 4 columns]

# %%
# Check data types
lat_lng_df.dtypes
# Out:
# MLSNumber       object
# address_new     object
# lat            float64
# lng            float64
# dtype: object

# %%
# Show clean datframe
lat_lng_df
# Out:
#         MLSNumber                           address_new        lat        lng
# 0      DENC518086        2615 Pecksniff  Wilmington, DE  39.734608 -75.661402
# 2     DENC2018974        2615 Pecksniff  Wilmington, DE  39.734608 -75.661402
# 4      DENC518982         4938 S Tupelo  Wilmington, DE  39.744655 -75.548391
# 5      DENC512992           15 Kristina  Wilmington, DE  39.744655 -75.548391
# 6      DENC512104        3251 Champions  Wilmington, DE  39.729664 -75.698656
# ...           ...                                   ...        ...        ...
# 5745   DENC520114            101 Meriden  Hockessin, DE  39.763823 -75.652016
# 5746   DENC520392    417 Snuff Mill Hill  Hockessin, DE  39.809390 -75.667333
# 5747  DENC2014038             400 Wilson  Hockessin, DE  39.780478 -75.717182
# 5748  DENC2005484         918 Old Public  Hockessin, DE  39.795708 -75.688011
# 5749   DENC526982  124 Croom Mills Drive  Hockessin, DE  39.755896 -75.704279
#
# [5576 rows x 4 columns]

# %% [markdown]
# ### Output Clean Files

# %%
# Output Clean Files 
Pub_Rec_df.to_csv("Resources/pub_rec_clean.csv", index=False)
broker_df.to_csv("Resources/broker_data_clean.csv", index=False)
ID_table_df.to_csv("Resources/id_table_clean.csv", index=False)
Mortgage_Data_df.to_csv("Resources/mortgage_data_clean.csv", index=False)
Sales_Data_df.to_csv("Resources/sales_data_clean.csv", index=False)
# Exclude Pub_remarks.csv - data is unstructured
#Pub_Remarks_df.to_csv("Resources/pub_remarks_clean.csv", index=False)
Prop_Charac_df.to_csv("Resources/prop_charac_clean.csv", index=False)
lat_lng_df.to_csv("Resources/lat_lng_clean.csv", index=False)
