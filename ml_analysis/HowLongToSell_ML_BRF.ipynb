# %%
import pandas as pd
import numpy as np
import psycopg2
import pathlib as Path
import datetime as dt
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Note - You must set up your own config file
from config import db_password

# %%
# Name the SQL database your are accessing
database = "RealLeads"

# Make your local connection to the database in PostgreSQL
conn = psycopg2.connect(
    host="localhost",
    database=database,
    user="postgres",
    password=db_password)

# %%
# Table selection Function
def table_select(table_name):
    table =f"select * from \"{table_name}\""
    dataFrame = pd.read_sql(table, conn)
    return dataFrame

# %%
# Names of the tables to be imported
prop_charac = table_select("prop_charac_clean")
pub_rec = table_select("pub_rec_clean")
sales_data = table_select("sales_data_clean")

# %%
prop_charac.head()
# Out:
#     MLSNumber             Address    BuildingName  Ownership  \
# 0  DENC518086   2615 Pecksniff Rd  NONE AVAILABLE  FeeSimple
# 1  DENC518982  4938 S Tupelo Turn            None  FeeSimple
# 2  DENC512992      15 Kristina Ct            None  FeeSimple
# 3  DENC512104   3251 Champions Dr            None  FeeSimple
# 4  DENC503480   3706 Lafayette St            None  FeeSimple
#
#   Senior_Community_YN Condo/Coop_Assoc_YN HOA_YN AssociationFee  \
# 0                  No                  No    Yes           $15
# 1                  No                  No     No           None
# 2                  No                  No     No           None
# 3                  No                  No    Yes           $50
# 4                  No                  No     No           None
#
#   AssociationFeeFrequency          Structure_Type  ...  Garage_YN  \
# 0                Annually                Detached  ...        Yes
# 1                    None  Interior Row/Townhouse  ...         No
# 2                    None  Interior Row/Townhouse  ...         No
# 3                Annually  Interior Row/Townhouse  ...        Yes
# 4                    None                Detached  ...         No
#
#   GarageSpaces GarageFeatures Parking  \
# 0          1.0           None    None
# 1          NaN           None    None
# 2          NaN           None    None
# 3          1.0           None    None
# 4          NaN           None    None
#
#                                     ExteriorFeatures  \
# 0  ExtensiveHardscape,Sidewalks,StoneRetainingWal...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                    ExteriorMaterial             Main_Roof  Foundation  \
# 0            BrickFront,VinylSiding  ArchitecturalShingle        None
# 1  AluminumSiding,Brick,VinylSiding               Asphalt        None
# 2                       VinylSiding                  None        None
# 3                             Other               Shingle        None
# 4                          Asbestos                  None        None
#
#         PorchDeck SwimmingPoolType
# 0  Patios,Porches             None
# 1            None             None
# 2            None             None
# 3          Patios             None
# 4            None             None
#
# [5 rows x 59 columns]

# %%
prop_charac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5576 entries, 0 to 5575
# Data columns (total 59 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   MLSNumber                  5576 non-null   object
#  1   Address                    5576 non-null   object
#  2   BuildingName               1139 non-null   object
#  3   Ownership                  5576 non-null   object
#  4   Senior_Community_YN        5576 non-null   object
#  5   Condo/Coop_Assoc_YN        5576 non-null   object
#  6   HOA_YN                     5576 non-null   object
#  7   AssociationFee             1582 non-null   object
#  8   AssociationFeeFrequency    1582 non-null   object
#  9   Structure_Type             5576 non-null   object
#  10  Acres                      5354 non-null   float64
#  11  LotDimensions              4847 non-null   object
#  12  LotDescription             1455 non-null   object
#  13  FeeIncludes                661 non-null    object
#  14  Age                        5576 non-null   float64
#  15  InteriorSqFt               5576 non-null   float64
#  16  Interior_SqFt_Source       5576 non-null   object
#  17  AboveGradeSqFt             5576 non-null   float64
#  18  BelowGradeSqFt             5394 non-null   float64
#  19  PropertyCondition          1916 non-null   object
#  20  Bedrooms                   5571 non-null   float64
#  21  Baths                      5571 non-null   float64
#  22  BathsFull                  5571 non-null   float64
#  23  PartialBaths               3939 non-null   float64
#  24  Design                     5576 non-null   object
#  25  Style                      5576 non-null   object
#  26  NumberofStories            5571 non-null   object
#  27  RoomCount                  1006 non-null   float64
#  28  InteriorFeatures           2693 non-null   object
#  29  Flooring                   2452 non-null   object
#  30  Central_Air_YN             5576 non-null   object
#  31  Cooling                    5576 non-null   object
#  32  PrimaryHeat                5576 non-null   object
#  33  HeatDelivery               5575 non-null   object
#  34  HotWater                   5328 non-null   object
#  35  ElectricalSystem           2001 non-null   object
#  36  Water                      5576 non-null   object
#  37  Sewer                      5576 non-null   object
#  38  Fireplace_YN               3309 non-null   object
#  39  FireplaceCount             4727 non-null   float64
#  40  FireplaceFeatures          1483 non-null   object
#  41  KitchenAppliancesFeatures  2414 non-null   object
#  42  CookingFuel                2414 non-null   object
#  43  LaundryHookUps             2897 non-null   object
#  44  Basement_YN                5576 non-null   object
#  45  BasementType               4687 non-null   object
#  46  BasementDescription        4687 non-null   object
#  47  BasementFootprintPct       234 non-null    float64
#  48  BasementFinishedPct        324 non-null    float64
#  49  Garage_YN                  5576 non-null   object
#  50  GarageSpaces               3406 non-null   float64
#  51  GarageFeatures             1370 non-null   object
#  52  Parking                    1370 non-null   object
#  53  ExteriorFeatures           2326 non-null   object
#  54  ExteriorMaterial           5576 non-null   object
#  55  Main_Roof                  2406 non-null   object
#  56  Foundation                 2137 non-null   object
#  57  PorchDeck                  2127 non-null   object
#  58  SwimmingPoolType           147 non-null    object
# dtypes: float64(14), object(45)
# memory usage: 2.5+ MB

# %%
pub_rec.head()
# Out:
#     MLSNumber         Tax_ID Address-truncated PropertyCityState Zip_Code  \
# 0  DENC518086  08-038.30-119   2615 Pecksniff     Wilmington, DE    19808
# 1  DENC518982  08-036.10-081    4938 S Tupelo     Wilmington, DE    19808
# 2  DENC512992  08-044.30-363      15 Kristina     Wilmington, DE    19808
# 3  DENC512104  08-036.40-376   3251 Champions     Wilmington, DE    19808
# 4  DENC503480  07-041.10-071   3706 Lafayette     Wilmington, DE    19808
#
#    Zip4 CarrierRoute PropDoNotMail       OwnerNames OwnerLastName  ...  \
# 0  3026         C010             N   James Robinson      Robinson  ...
# 1  1026         C009             N    Xiaopeng Deng          Deng  ...
# 2  4063         C084             N   Robert F Walls         Walls  ...
# 3  2601         C039             N  Michael J Downs         Downs  ...
# 4  6014         C001             N     Maria Corona        Corona  ...
#
#   BldgSqFtTotal Stories Bedrooms                Exterior  BsmtDesc  \
# 0        1875.0     1.0      3.0  Brick, Aluminum, Vinyl  Finished
# 1        1575.0     2.0      3.0  Brick, Aluminum, Vinyl  Finished
# 2           NaN     2.0      2.0         Aluminum, Vinyl      None
# 3           NaN     2.0      2.0                   Other      None
# 4           NaN     1.0      3.0                Asbestos      None
#
#   FireplaceTotal           GrgType     HeatDelivery YearBuilt YearRemod
# 0            0.0  Att/BuiltIn/Bsmt  Hot Water/Steam      1958         0
# 1            0.0              None     Hot/Warm Air      1976         0
# 2            0.0              None        Heat Pump      1985         0
# 3            1.0  Att/BuiltIn/Bsmt        Heat Pump      1985         0
# 4            0.0              None     Hot/Warm Air      1957         0
#
# [5 rows x 58 columns]

# %%
pub_rec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5576 entries, 0 to 5575
# Data columns (total 58 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   MLSNumber                5576 non-null   object
#  1   Tax_ID                   5576 non-null   object
#  2   Address-truncated        5576 non-null   object
#  3   PropertyCityState        5576 non-null   object
#  4   Zip_Code                 5576 non-null   object
#  5   Zip4                     5576 non-null   object
#  6   CarrierRoute             5572 non-null   object
#  7   PropDoNotMail            5573 non-null   object
#  8   OwnerNames               5246 non-null   object
#  9   OwnerLastName            5206 non-null   object
#  10  OwnerFirstName           4917 non-null   object
#  11  Owner2LastName           2359 non-null   object
#  12  Owner2FirstName          2359 non-null   object
#  13  Owner3LastName           89 non-null     object
#  14  Owner3FirstName          89 non-null     object
#  15  OwnerAddress             5257 non-null   object
#  16  OwnerCityState           5251 non-null   object
#  17  OwnerZipCode             5576 non-null   object
#  18  OwnerZip4                5576 non-null   object
#  19  OwnerCarrierRoute        4967 non-null   object
#  20  OwnerOccupied            5576 non-null   bool
#  21  Municipality             5576 non-null   object
#  22  SubdivisionNeighborhood  5288 non-null   object
#  23  TaxIDAlt                 4372 non-null   object
#  24  TaxMap                   5576 non-null   object
#  25  Block                    5064 non-null   object
#  26  Lot                      5576 non-null   object
#  27  SchoolDistrict           5576 non-null   object
#  28  TaxYear                  5576 non-null   int64
#  29  AnnualTax                5576 non-null   int64
#  30  CountyTax                5576 non-null   int64
#  31  MunicipalTax             5576 non-null   int64
#  32  SchoolTax                5576 non-null   int64
#  33  TotalLandAsmt            5576 non-null   int64
#  34  TotalBldgAsmt            5576 non-null   int64
#  35  TaxableTotalAsmt         5576 non-null   int64
#  36  DeedRecordDate           5553 non-null   object
#  37  SettleDate               5044 non-null   object
#  38  SaleAmt                  5576 non-null   int64
#  39  SaleType                 2573 non-null   object
#  40  PropertyClass            5576 non-null   object
#  41  CondoYN                  5576 non-null   object
#  42  LotFrontage              5576 non-null   float64
#  43  LotDepth                 5576 non-null   float64
#  44  LotSqFt                  5576 non-null   int64
#  45  LotAcres                 5576 non-null   float64
#  46  LotShape                 2201 non-null   object
#  47  Zoning                   5576 non-null   object
#  48  BldgSqFtTotal            2514 non-null   float64
#  49  Stories                  5576 non-null   float64
#  50  Bedrooms                 5498 non-null   float64
#  51  Exterior                 5400 non-null   object
#  52  BsmtDesc                 968 non-null    object
#  53  FireplaceTotal           5498 non-null   float64
#  54  GrgType                  3648 non-null   object
#  55  HeatDelivery             5417 non-null   object
#  56  YearBuilt                5576 non-null   object
#  57  YearRemod                5576 non-null   object
# dtypes: bool(1), float64(7), int64(10), object(40)
# memory usage: 2.4+ MB

# %%
sales_data.head()
# Out:
#     MLSNumber             Address  Status  Sold_Price  \
# 0  DENC518086   2615 Pecksniff Rd  Closed    335000.0
# 1  DENC518982  4938 S Tupelo Turn  Closed    200000.0
# 2  DENC512992      15 Kristina Ct  Closed    200000.0
# 3  DENC512104   3251 Champions Dr  Closed    200000.0
# 4  DENC503480   3706 Lafayette St  Closed    200000.0
#
#    Sold_Price_less_Concession  Orig_List_Price  Current_List_Price  \
# 0                    335000.0         330000.0            330000.0
# 1                    200000.0         215500.0            210000.0
# 2                    200000.0         200000.0            200000.0
# 3                    200000.0         219900.0            214900.0
# 4                    200000.0         190000.0            190000.0
#
#    Days_on_Market  Previous_Days_on_Market    ListDate  StatusDate  \
# 0             5.0                      5.0  2020-12-11  2021-02-11
# 1            47.0                     67.0  2021-01-07  2021-04-08
# 2            15.0                     15.0  2020-12-28  2021-02-26
# 3            11.0                     11.0  2020-10-27  2020-12-14
# 4             3.0                      3.0  2020-06-20  2020-08-02
#
#   Agreement_of_Sale_Date SettledDate Concessions_YN Concessions_Remarks  \
# 0             2020-12-16  2021-02-11             No                None
# 1             2021-02-21  2021-04-08             No                None
# 2             2021-01-09  2021-02-26             No                None
# 3             2020-11-05  2020-12-11             No                None
# 4             2020-06-21  2020-07-31             No                None
#
#    SellerConcessionsAmount FinalFinancing
# 0                      0.0            FHA
# 1                      0.0   Conventional
# 2                      0.0   Conventional
# 3                      0.0   Conventional
# 4                      0.0   Conventional

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5576 entries, 0 to 5575
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   MLSNumber                   5576 non-null   object
#  1   Address                     5576 non-null   object
#  2   Status                      5576 non-null   object
#  3   Sold_Price                  5576 non-null   float64
#  4   Sold_Price_less_Concession  5576 non-null   float64
#  5   Orig_List_Price             5576 non-null   float64
#  6   Current_List_Price          5576 non-null   float64
#  7   Days_on_Market              5576 non-null   float64
#  8   Previous_Days_on_Market     5576 non-null   float64
#  9   ListDate                    5576 non-null   object
#  10  StatusDate                  5576 non-null   object
#  11  Agreement_of_Sale_Date      5576 non-null   object
#  12  SettledDate                 5576 non-null   object
#  13  Concessions_YN              5576 non-null   object
#  14  Concessions_Remarks         339 non-null    object
#  15  SellerConcessionsAmount     5576 non-null   float64
#  16  FinalFinancing              5576 non-null   object
# dtypes: float64(7), object(10)
# memory usage: 740.7+ KB

# %%
sales_data['ListDate'].head()
# Out:
# 0    2020-12-11
# 1    2021-01-07
# 2    2020-12-28
# 3    2020-10-27
# 4    2020-06-20
# Name: ListDate, dtype: object

# %%
sales_data['ListDate'] = pd.to_datetime(sales_data['ListDate'])

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5576 entries, 0 to 5575
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   MLSNumber                   5576 non-null   object
#  1   Address                     5576 non-null   object
#  2   Status                      5576 non-null   object
#  3   Sold_Price                  5576 non-null   float64
#  4   Sold_Price_less_Concession  5576 non-null   float64
#  5   Orig_List_Price             5576 non-null   float64
#  6   Current_List_Price          5576 non-null   float64
#  7   Days_on_Market              5576 non-null   float64
#  8   Previous_Days_on_Market     5576 non-null   float64
#  9   ListDate                    5576 non-null   datetime64[ns]
#  10  StatusDate                  5576 non-null   object
#  11  Agreement_of_Sale_Date      5576 non-null   object
#  12  SettledDate                 5576 non-null   object
#  13  Concessions_YN              5576 non-null   object
#  14  Concessions_Remarks         339 non-null    object
#  15  SellerConcessionsAmount     5576 non-null   float64
#  16  FinalFinancing              5576 non-null   object
# dtypes: datetime64[ns](1), float64(7), object(9)
# memory usage: 740.7+ KB

# %%
sales_data['Month'] = pd.DatetimeIndex(sales_data['ListDate']).month

# %%
sales_data['Year'] = pd.DatetimeIndex(sales_data['ListDate']).year

# %%
# Drop Rows from prop_charac
prop_charac = prop_charac[['MLSNumber',
                            'Bedrooms',
                            'Baths',
                            'Basement_YN',
                            'Garage_YN',
                            'AboveGradeSqFt',
                            'BelowGradeSqFt',
                            'Condo/Coop_Assoc_YN',
                            'Central_Air_YN',
                            'HOA_YN',
                            'Age',
                          'Ownership',
                          'Structure_Type',
                          'InteriorSqFt',
                          'NumberofStories']]

prop_charac
# Out:
#         MLSNumber  Bedrooms  Baths Basement_YN Garage_YN  AboveGradeSqFt  \
# 0      DENC518086       4.0    2.0         Yes       Yes          2099.0
# 1      DENC518982       3.0    2.0         Yes        No          1575.0
# 2      DENC512992       2.0    2.0         Yes        No          1150.0
# 3      DENC512104       2.0    3.0         Yes       Yes          1425.0
# 4      DENC503480       3.0    2.0         Yes        No           925.0
# ...           ...       ...    ...         ...       ...             ...
# 5571   DENC520114       3.0    2.0         Yes       Yes          3045.0
# 5572   DENC520392       4.0    4.0         Yes       Yes          3175.0
# 5573  DENC2014038       4.0    3.0         Yes       Yes          2850.0
# 5574  DENC2005484       4.0    3.0         Yes       Yes          3425.0
# 5575   DENC526982       2.0    2.0          No       Yes          1950.0
#
#       BelowGradeSqFt Condo/Coop_Assoc_YN Central_Air_YN HOA_YN     Age  \
# 0                0.0                  No            Yes    Yes  1958.0
# 1              352.0                  No            Yes     No  1976.0
# 2                0.0                  No            Yes     No  1985.0
# 3                0.0                  No            Yes    Yes  1985.0
# 4                0.0                  No            Yes     No  1957.0
# ...              ...                 ...            ...    ...     ...
# 5571             0.0                  No            Yes    Yes  1958.0
# 5572           636.0                  No            Yes    Yes  1973.0
# 5573           341.0                  No            Yes     No  1989.0
# 5574             0.0                  No            Yes     No  1992.0
# 5575             0.0                  No            Yes    Yes  2002.0
#
#       Ownership          Structure_Type  InteriorSqFt     NumberofStories
# 0     FeeSimple                Detached        2099.0         Main,Upper1
# 1     FeeSimple  Interior Row/Townhouse        1927.0         Main,Upper1
# 2     FeeSimple  Interior Row/Townhouse        1150.0         Main,Upper1
# 3     FeeSimple  Interior Row/Townhouse        1425.0         Main,Upper1
# 4     FeeSimple                Detached         925.0                Main
# ...         ...                     ...           ...                 ...
# 5571  FeeSimple                Detached        3045.0         Lower1,Main
# 5572  FeeSimple                Detached        3811.0  Lower1,Main,Upper1
# 5573  FeeSimple                Detached        3191.0  Lower1,Main,Upper1
# 5574  FeeSimple                Detached        3425.0  Lower1,Main,Upper1
# 5575  FeeSimple  Interior Row/Townhouse        1950.0         Main,Upper1
#
# [5576 rows x 15 columns]

# %%
# Drop Rows from pub_rec
pub_rec = pub_rec[['MLSNumber',
                    'Zip_Code',
                    'SchoolDistrict',
                    'AnnualTax',
                    'LotAcres',
                    'SubdivisionNeighborhood',
                    'Municipality',
                      'Lot',
                      'OwnerOccupied',
                      'TotalLandAsmt',
                  'TotalBldgAsmt',
                  'PropertyClass',
                  'YearBuilt']]

pub_rec
# Out:
#         MLSNumber Zip_Code         SchoolDistrict  AnnualTax  LotAcres  \
# 0      DENC518086    19808  Red Clay Consolidated       2151      0.26
# 1      DENC518982    19808  Red Clay Consolidated       1824      0.06
# 2      DENC512992    19808  Red Clay Consolidated       1563      0.05
# 3      DENC512104    19808  Red Clay Consolidated       2174      0.05
# 4      DENC503480    19808  Red Clay Consolidated       1349      0.17
# ...           ...      ...                    ...        ...       ...
# 5571   DENC520114    19707  Red Clay Consolidated       4311      1.03
# 5572   DENC520392    19707  Red Clay Consolidated       5208      0.75
# 5573  DENC2014038    19707  Red Clay Consolidated       4407      0.39
# 5574  DENC2005484    19707  Red Clay Consolidated       4825      0.54
# 5575   DENC526982    19707  Red Clay Consolidated       3193      0.07
#
#      SubdivisionNeighborhood        Municipality  Lot  OwnerOccupied  \
# 0           Sherwood Park Ii  Mill Creek Hundred  119           True
# 1               Pepper Ridge  Mill Creek Hundred   81          False
# 2                   Woodmill  Mill Creek Hundred  363          False
# 3              Fairway Falls  Mill Creek Hundred  376           True
# 4            Washington Hgts  Christiana Hundred   71           True
# ...                      ...                 ...  ...            ...
# 5571        Canterbury Hills  Mill Creek Hundred   46           True
# 5572                    None  Christiana Hundred   54           True
# 5573          Stenning Woods  Mill Creek Hundred   27           True
# 5574       Quaker Lea Villas  Mill Creek Hundred   16           True
# 5575           Adare Village  Mill Creek Hundred  266           True
#
#       TotalLandAsmt  TotalBldgAsmt PropertyClass YearBuilt
# 0             12600          52600   Residential      1958
# 1              9900          45400   Residential      1976
# 2              9400          38000   Residential      1985
# 3              8600          57300   Residential      1985
# 4              8600          32300   Residential      1957
# ...             ...            ...           ...       ...
# 5571          31300          99400   Residential      1958
# 5572          25200         132700   Residential      1973
# 5573          30000         103600   Residential      1989
# 5574          28500         117800   Residential      1992
# 5575          21500          75300   Residential      2002
#
# [5576 rows x 13 columns]

# %%
# Drop Rows from sales_data

sales_data = sales_data[['MLSNumber',
                        'Days_on_Market',
                        'Orig_List_Price',
                         'Month',
                         'Year'
                        ]]

sales_data
# Out:
#         MLSNumber  Days_on_Market  Orig_List_Price  Month  Year
# 0      DENC518086             5.0         330000.0     12  2020
# 1      DENC518982            47.0         215500.0      1  2021
# 2      DENC512992            15.0         200000.0     12  2020
# 3      DENC512104            11.0         219900.0     10  2020
# 4      DENC503480             3.0         190000.0      6  2020
# ...           ...             ...              ...    ...   ...
# 5571   DENC520114             5.0         595000.0      6  2021
# 5572   DENC520392            25.0         639000.0      3  2021
# 5573  DENC2014038             7.0         529900.0      1  2022
# 5574  DENC2005484            25.0         620000.0      8  2021
# 5575   DENC526982            51.0         350000.0      5  2021
#
# [5576 rows x 5 columns]

# %%
# Merge sales_data and pub_rec dataframes
merge_df = pd.merge(sales_data, pub_rec, on='MLSNumber')
merge_df
# Out:
#         MLSNumber  Days_on_Market  Orig_List_Price  Month  Year Zip_Code  \
# 0      DENC518086             5.0         330000.0     12  2020    19808
# 1      DENC518982            47.0         215500.0      1  2021    19808
# 2      DENC512992            15.0         200000.0     12  2020    19808
# 3      DENC512104            11.0         219900.0     10  2020    19808
# 4      DENC503480             3.0         190000.0      6  2020    19808
# ...           ...             ...              ...    ...   ...      ...
# 5571   DENC520114             5.0         595000.0      6  2021    19707
# 5572   DENC520392            25.0         639000.0      3  2021    19707
# 5573  DENC2014038             7.0         529900.0      1  2022    19707
# 5574  DENC2005484            25.0         620000.0      8  2021    19707
# 5575   DENC526982            51.0         350000.0      5  2021    19707
#
#              SchoolDistrict  AnnualTax  LotAcres SubdivisionNeighborhood  \
# 0     Red Clay Consolidated       2151      0.26        Sherwood Park Ii
# 1     Red Clay Consolidated       1824      0.06            Pepper Ridge
# 2     Red Clay Consolidated       1563      0.05                Woodmill
# 3     Red Clay Consolidated       2174      0.05           Fairway Falls
# 4     Red Clay Consolidated       1349      0.17         Washington Hgts
# ...                     ...        ...       ...                     ...
# 5571  Red Clay Consolidated       4311      1.03        Canterbury Hills
# 5572  Red Clay Consolidated       5208      0.75                    None
# 5573  Red Clay Consolidated       4407      0.39          Stenning Woods
# 5574  Red Clay Consolidated       4825      0.54       Quaker Lea Villas
# 5575  Red Clay Consolidated       3193      0.07           Adare Village
#
#             Municipality  Lot  OwnerOccupied  TotalLandAsmt  TotalBldgAsmt  \
# 0     Mill Creek Hundred  119           True          12600          52600
# 1     Mill Creek Hundred   81          False           9900          45400
# 2     Mill Creek Hundred  363          False           9400          38000
# 3     Mill Creek Hundred  376           True           8600          57300
# 4     Christiana Hundred   71           True           8600          32300
# ...                  ...  ...            ...            ...            ...
# 5571  Mill Creek Hundred   46           True          31300          99400
# 5572  Christiana Hundred   54           True          25200         132700
# 5573  Mill Creek Hundred   27           True          30000         103600
# 5574  Mill Creek Hundred   16           True          28500         117800
# 5575  Mill Creek Hundred  266           True          21500          75300
#
#      PropertyClass YearBuilt
# 0      Residential      1958
# 1      Residential      1976
# 2      Residential      1985
# 3      Residential      1985
# 4      Residential      1957
# ...            ...       ...
# 5571   Residential      1958
# 5572   Residential      1973
# 5573   Residential      1989
# 5574   Residential      1992
# 5575   Residential      2002
#
# [5576 rows x 17 columns]

# %%
# Merge merge_df and prop_charac dataframes
merge_df = pd.merge(merge_df, prop_charac, on='MLSNumber')
merge_df
# Out:
#         MLSNumber  Days_on_Market  Orig_List_Price  Month  Year Zip_Code  \
# 0      DENC518086             5.0         330000.0     12  2020    19808
# 1      DENC518982            47.0         215500.0      1  2021    19808
# 2      DENC512992            15.0         200000.0     12  2020    19808
# 3      DENC512104            11.0         219900.0     10  2020    19808
# 4      DENC503480             3.0         190000.0      6  2020    19808
# ...           ...             ...              ...    ...   ...      ...
# 5571   DENC520114             5.0         595000.0      6  2021    19707
# 5572   DENC520392            25.0         639000.0      3  2021    19707
# 5573  DENC2014038             7.0         529900.0      1  2022    19707
# 5574  DENC2005484            25.0         620000.0      8  2021    19707
# 5575   DENC526982            51.0         350000.0      5  2021    19707
#
#              SchoolDistrict  AnnualTax  LotAcres SubdivisionNeighborhood  ...  \
# 0     Red Clay Consolidated       2151      0.26        Sherwood Park Ii  ...
# 1     Red Clay Consolidated       1824      0.06            Pepper Ridge  ...
# 2     Red Clay Consolidated       1563      0.05                Woodmill  ...
# 3     Red Clay Consolidated       2174      0.05           Fairway Falls  ...
# 4     Red Clay Consolidated       1349      0.17         Washington Hgts  ...
# ...                     ...        ...       ...                     ...  ...
# 5571  Red Clay Consolidated       4311      1.03        Canterbury Hills  ...
# 5572  Red Clay Consolidated       5208      0.75                    None  ...
# 5573  Red Clay Consolidated       4407      0.39          Stenning Woods  ...
# 5574  Red Clay Consolidated       4825      0.54       Quaker Lea Villas  ...
# 5575  Red Clay Consolidated       3193      0.07           Adare Village  ...
#
#      AboveGradeSqFt BelowGradeSqFt  Condo/Coop_Assoc_YN  Central_Air_YN  \
# 0            2099.0            0.0                   No             Yes
# 1            1575.0          352.0                   No             Yes
# 2            1150.0            0.0                   No             Yes
# 3            1425.0            0.0                   No             Yes
# 4             925.0            0.0                   No             Yes
# ...             ...            ...                  ...             ...
# 5571         3045.0            0.0                   No             Yes
# 5572         3175.0          636.0                   No             Yes
# 5573         2850.0          341.0                   No             Yes
# 5574         3425.0            0.0                   No             Yes
# 5575         1950.0            0.0                   No             Yes
#
#       HOA_YN     Age  Ownership          Structure_Type  InteriorSqFt  \
# 0        Yes  1958.0  FeeSimple                Detached        2099.0
# 1         No  1976.0  FeeSimple  Interior Row/Townhouse        1927.0
# 2         No  1985.0  FeeSimple  Interior Row/Townhouse        1150.0
# 3        Yes  1985.0  FeeSimple  Interior Row/Townhouse        1425.0
# 4         No  1957.0  FeeSimple                Detached         925.0
# ...      ...     ...        ...                     ...           ...
# 5571     Yes  1958.0  FeeSimple                Detached        3045.0
# 5572     Yes  1973.0  FeeSimple                Detached        3811.0
# 5573      No  1989.0  FeeSimple                Detached        3191.0
# 5574      No  1992.0  FeeSimple                Detached        3425.0
# 5575     Yes  2002.0  FeeSimple  Interior Row/Townhouse        1950.0
#
#          NumberofStories
# 0            Main,Upper1
# 1            Main,Upper1
# 2            Main,Upper1
# 3            Main,Upper1
# 4                   Main
# ...                  ...
# 5571         Lower1,Main
# 5572  Lower1,Main,Upper1
# 5573  Lower1,Main,Upper1
# 5574  Lower1,Main,Upper1
# 5575         Main,Upper1
#
# [5576 rows x 31 columns]

# %%
# Info for all columns in new dataframe
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5576 entries, 0 to 5575
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   MLSNumber                5576 non-null   object
#  1   Days_on_Market           5576 non-null   float64
#  2   Orig_List_Price          5576 non-null   float64
#  3   Month                    5576 non-null   int64
#  4   Year                     5576 non-null   int64
#  5   Zip_Code                 5576 non-null   object
#  6   SchoolDistrict           5576 non-null   object
#  7   AnnualTax                5576 non-null   int64
#  8   LotAcres                 5576 non-null   float64
#  9   SubdivisionNeighborhood  5288 non-null   object
#  10  Municipality             5576 non-null   object
#  11  Lot                      5576 non-null   object
#  12  OwnerOccupied            5576 non-null   bool
#  13  TotalLandAsmt            5576 non-null   int64
#  14  TotalBldgAsmt            5576 non-null   int64
#  15  PropertyClass            5576 non-null   object
#  16  YearBuilt                5576 non-null   object
#  17  Bedrooms                 5571 non-null   float64
#  18  Baths                    5571 non-null   float64
#  19  Basement_YN              5576 non-null   object
#  20  Garage_YN                5576 non-null   object
#  21  AboveGradeSqFt           5576 non-null   float64
#  22  BelowGradeSqFt           5394 non-null   float64
#  23  Condo/Coop_Assoc_YN      5576 non-null   object
#  24  Central_Air_YN           5576 non-null   object
#  25  HOA_YN                   5576 non-null   object
#  26  Age                      5576 non-null   float64
#  27  Ownership                5576 non-null   object
#  28  Structure_Type           5576 non-null   object
#  29  InteriorSqFt             5576 non-null   float64
#  30  NumberofStories          5571 non-null   object
# dtypes: bool(1), float64(9), int64(5), object(16)
# memory usage: 1.3+ MB

# %%
# Determine the number of unique values in each column.
merge_df.nunique()
# Out:
# MLSNumber                  5576
# Days_on_Market              200
# Orig_List_Price             618
# Month                        12
# Year                          6
# Zip_Code                     15
# SchoolDistrict                4
# AnnualTax                  2540
# LotAcres                    173
# SubdivisionNeighborhood     619
# Municipality                 12
# Lot                         844
# OwnerOccupied                 2
# TotalLandAsmt               376
# TotalBldgAsmt              1139
# PropertyClass                 4
# YearBuilt                   154
# Bedrooms                      9
# Baths                         7
# Basement_YN                   2
# Garage_YN                     2
# AboveGradeSqFt              478
# BelowGradeSqFt              611
# Condo/Coop_Assoc_YN           2
# Central_Air_YN                2
# HOA_YN                        2
# Age                         166
# Ownership                     4
# Structure_Type                9
# InteriorSqFt               1133
# NumberofStories              35
# dtype: int64

# %%
# Find null rows
merge_df.isna().sum()
# Out:
# MLSNumber                    0
# Days_on_Market               0
# Orig_List_Price              0
# Month                        0
# Year                         0
# Zip_Code                     0
# SchoolDistrict               0
# AnnualTax                    0
# LotAcres                     0
# SubdivisionNeighborhood    288
# Municipality                 0
# Lot                          0
# OwnerOccupied                0
# TotalLandAsmt                0
# TotalBldgAsmt                0
# PropertyClass                0
# YearBuilt                    0
# Bedrooms                     5
# Baths                        5
# Basement_YN                  0
# Garage_YN                    0
# AboveGradeSqFt               0
# BelowGradeSqFt             182
# Condo/Coop_Assoc_YN          0
# Central_Air_YN               0
# HOA_YN                       0
# Age                          0
# Ownership                    0
# Structure_Type               0
# InteriorSqFt                 0
# NumberofStories              5
# dtype: int64

# %%
# Drop rows with null values
merge_df = merge_df.dropna()
merge_df
# Out:
#         MLSNumber  Days_on_Market  Orig_List_Price  Month  Year Zip_Code  \
# 0      DENC518086             5.0         330000.0     12  2020    19808
# 1      DENC518982            47.0         215500.0      1  2021    19808
# 2      DENC512992            15.0         200000.0     12  2020    19808
# 3      DENC512104            11.0         219900.0     10  2020    19808
# 4      DENC503480             3.0         190000.0      6  2020    19808
# ...           ...             ...              ...    ...   ...      ...
# 5570  DENC2013538             5.0         589900.0     12  2021    19707
# 5571   DENC520114             5.0         595000.0      6  2021    19707
# 5573  DENC2014038             7.0         529900.0      1  2022    19707
# 5574  DENC2005484            25.0         620000.0      8  2021    19707
# 5575   DENC526982            51.0         350000.0      5  2021    19707
#
#              SchoolDistrict  AnnualTax  LotAcres SubdivisionNeighborhood  ...  \
# 0     Red Clay Consolidated       2151      0.26        Sherwood Park Ii  ...
# 1     Red Clay Consolidated       1824      0.06            Pepper Ridge  ...
# 2     Red Clay Consolidated       1563      0.05                Woodmill  ...
# 3     Red Clay Consolidated       2174      0.05           Fairway Falls  ...
# 4     Red Clay Consolidated       1349      0.17         Washington Hgts  ...
# ...                     ...        ...       ...                     ...  ...
# 5570  Red Clay Consolidated       3503      0.82          Berkeley Ridge  ...
# 5571  Red Clay Consolidated       4311      1.03        Canterbury Hills  ...
# 5573  Red Clay Consolidated       4407      0.39          Stenning Woods  ...
# 5574  Red Clay Consolidated       4825      0.54       Quaker Lea Villas  ...
# 5575  Red Clay Consolidated       3193      0.07           Adare Village  ...
#
#      AboveGradeSqFt BelowGradeSqFt  Condo/Coop_Assoc_YN  Central_Air_YN  \
# 0            2099.0            0.0                   No             Yes
# 1            1575.0          352.0                   No             Yes
# 2            1150.0            0.0                   No             Yes
# 3            1425.0            0.0                   No             Yes
# 4             925.0            0.0                   No             Yes
# ...             ...            ...                  ...             ...
# 5570         2425.0            0.0                   No             Yes
# 5571         3045.0            0.0                   No             Yes
# 5573         2850.0          341.0                   No             Yes
# 5574         3425.0            0.0                   No             Yes
# 5575         1950.0            0.0                   No             Yes
#
#       HOA_YN     Age  Ownership          Structure_Type  InteriorSqFt  \
# 0        Yes  1958.0  FeeSimple                Detached        2099.0
# 1         No  1976.0  FeeSimple  Interior Row/Townhouse        1927.0
# 2         No  1985.0  FeeSimple  Interior Row/Townhouse        1150.0
# 3        Yes  1985.0  FeeSimple  Interior Row/Townhouse        1425.0
# 4         No  1957.0  FeeSimple                Detached         925.0
# ...      ...     ...        ...                     ...           ...
# 5570      No  1957.0  FeeSimple                Detached        2425.0
# 5571     Yes  1958.0  FeeSimple                Detached        3045.0
# 5573      No  1989.0  FeeSimple                Detached        3191.0
# 5574      No  1992.0  FeeSimple                Detached        3425.0
# 5575     Yes  2002.0  FeeSimple  Interior Row/Townhouse        1950.0
#
#          NumberofStories
# 0            Main,Upper1
# 1            Main,Upper1
# 2            Main,Upper1
# 3            Main,Upper1
# 4                   Main
# ...                  ...
# 5570         Lower1,Main
# 5571         Lower1,Main
# 5573  Lower1,Main,Upper1
# 5574  Lower1,Main,Upper1
# 5575         Main,Upper1
#
# [5110 rows x 31 columns]

# %%
# Find max days on market
merge_df['Days_on_Market'].max()
# Out:
# 655.0

# %%
# Check binning
pd.cut(merge_df['Days_on_Market'], bins=8).value_counts()
# Out:
# (-0.655, 81.875]     4931
# (81.875, 163.75]      136
# (163.75, 245.625]      20
# (245.625, 327.5]       13
# (327.5, 409.375]        4
# (491.25, 573.125]       3
# (573.125, 655.0]        2
# (409.375, 491.25]       1
# Name: Days_on_Market, dtype: int64

# %%
# Drop rows with condition over 120 days on market
merge_df.drop(merge_df[merge_df['Days_on_Market'] >= 120].index, inplace = True)
# Out:
# C:\Users\madel\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
clean_df = merge_df.copy()

# %%
# Cut data
cut_labels = ['Less than 2 months', 'More than 2 months']
cut_bins = [-1, 60, 120]
clean_df['DaysOnMarket_Buckets'] = pd.cut(clean_df['Days_on_Market'], bins=cut_bins, labels=cut_labels)
clean_df
# Out:
#         MLSNumber  Days_on_Market  Orig_List_Price  Month  Year Zip_Code  \
# 0      DENC518086             5.0         330000.0     12  2020    19808
# 1      DENC518982            47.0         215500.0      1  2021    19808
# 2      DENC512992            15.0         200000.0     12  2020    19808
# 3      DENC512104            11.0         219900.0     10  2020    19808
# 4      DENC503480             3.0         190000.0      6  2020    19808
# ...           ...             ...              ...    ...   ...      ...
# 5570  DENC2013538             5.0         589900.0     12  2021    19707
# 5571   DENC520114             5.0         595000.0      6  2021    19707
# 5573  DENC2014038             7.0         529900.0      1  2022    19707
# 5574  DENC2005484            25.0         620000.0      8  2021    19707
# 5575   DENC526982            51.0         350000.0      5  2021    19707
#
#              SchoolDistrict  AnnualTax  LotAcres SubdivisionNeighborhood  ...  \
# 0     Red Clay Consolidated       2151      0.26        Sherwood Park Ii  ...
# 1     Red Clay Consolidated       1824      0.06            Pepper Ridge  ...
# 2     Red Clay Consolidated       1563      0.05                Woodmill  ...
# 3     Red Clay Consolidated       2174      0.05           Fairway Falls  ...
# 4     Red Clay Consolidated       1349      0.17         Washington Hgts  ...
# ...                     ...        ...       ...                     ...  ...
# 5570  Red Clay Consolidated       3503      0.82          Berkeley Ridge  ...
# 5571  Red Clay Consolidated       4311      1.03        Canterbury Hills  ...
# 5573  Red Clay Consolidated       4407      0.39          Stenning Woods  ...
# 5574  Red Clay Consolidated       4825      0.54       Quaker Lea Villas  ...
# 5575  Red Clay Consolidated       3193      0.07           Adare Village  ...
#
#      BelowGradeSqFt Condo/Coop_Assoc_YN  Central_Air_YN  HOA_YN     Age  \
# 0               0.0                  No             Yes     Yes  1958.0
# 1             352.0                  No             Yes      No  1976.0
# 2               0.0                  No             Yes      No  1985.0
# 3               0.0                  No             Yes     Yes  1985.0
# 4               0.0                  No             Yes      No  1957.0
# ...             ...                 ...             ...     ...     ...
# 5570            0.0                  No             Yes      No  1957.0
# 5571            0.0                  No             Yes     Yes  1958.0
# 5573          341.0                  No             Yes      No  1989.0
# 5574            0.0                  No             Yes      No  1992.0
# 5575            0.0                  No             Yes     Yes  2002.0
#
#       Ownership          Structure_Type  InteriorSqFt     NumberofStories  \
# 0     FeeSimple                Detached        2099.0         Main,Upper1
# 1     FeeSimple  Interior Row/Townhouse        1927.0         Main,Upper1
# 2     FeeSimple  Interior Row/Townhouse        1150.0         Main,Upper1
# 3     FeeSimple  Interior Row/Townhouse        1425.0         Main,Upper1
# 4     FeeSimple                Detached         925.0                Main
# ...         ...                     ...           ...                 ...
# 5570  FeeSimple                Detached        2425.0         Lower1,Main
# 5571  FeeSimple                Detached        3045.0         Lower1,Main
# 5573  FeeSimple                Detached        3191.0  Lower1,Main,Upper1
# 5574  FeeSimple                Detached        3425.0  Lower1,Main,Upper1
# 5575  FeeSimple  Interior Row/Townhouse        1950.0         Main,Upper1
#
#      DaysOnMarket_Buckets
# 0      Less than 2 months
# 1      Less than 2 months
# 2      Less than 2 months
# 3      Less than 2 months
# 4      Less than 2 months
# ...                   ...
# 5570   Less than 2 months
# 5571   Less than 2 months
# 5573   Less than 2 months
# 5574   Less than 2 months
# 5575   Less than 2 months
#
# [5019 rows x 32 columns]

# %%
# Change index to MLSNumber
clean_df = clean_df.set_index('MLSNumber')
clean_df
# Out:
#              Days_on_Market  Orig_List_Price  Month  Year Zip_Code  \
# MLSNumber
# DENC518086              5.0         330000.0     12  2020    19808
# DENC518982             47.0         215500.0      1  2021    19808
# DENC512992             15.0         200000.0     12  2020    19808
# DENC512104             11.0         219900.0     10  2020    19808
# DENC503480              3.0         190000.0      6  2020    19808
# ...                     ...              ...    ...   ...      ...
# DENC2013538             5.0         589900.0     12  2021    19707
# DENC520114              5.0         595000.0      6  2021    19707
# DENC2014038             7.0         529900.0      1  2022    19707
# DENC2005484            25.0         620000.0      8  2021    19707
# DENC526982             51.0         350000.0      5  2021    19707
#
#                     SchoolDistrict  AnnualTax  LotAcres  \
# MLSNumber
# DENC518086   Red Clay Consolidated       2151      0.26
# DENC518982   Red Clay Consolidated       1824      0.06
# DENC512992   Red Clay Consolidated       1563      0.05
# DENC512104   Red Clay Consolidated       2174      0.05
# DENC503480   Red Clay Consolidated       1349      0.17
# ...                            ...        ...       ...
# DENC2013538  Red Clay Consolidated       3503      0.82
# DENC520114   Red Clay Consolidated       4311      1.03
# DENC2014038  Red Clay Consolidated       4407      0.39
# DENC2005484  Red Clay Consolidated       4825      0.54
# DENC526982   Red Clay Consolidated       3193      0.07
#
#             SubdivisionNeighborhood        Municipality  ... BelowGradeSqFt  \
# MLSNumber                                                ...
# DENC518086         Sherwood Park Ii  Mill Creek Hundred  ...            0.0
# DENC518982             Pepper Ridge  Mill Creek Hundred  ...          352.0
# DENC512992                 Woodmill  Mill Creek Hundred  ...            0.0
# DENC512104            Fairway Falls  Mill Creek Hundred  ...            0.0
# DENC503480          Washington Hgts  Christiana Hundred  ...            0.0
# ...                             ...                 ...  ...            ...
# DENC2013538          Berkeley Ridge  Mill Creek Hundred  ...            0.0
# DENC520114         Canterbury Hills  Mill Creek Hundred  ...            0.0
# DENC2014038          Stenning Woods  Mill Creek Hundred  ...          341.0
# DENC2005484       Quaker Lea Villas  Mill Creek Hundred  ...            0.0
# DENC526982            Adare Village  Mill Creek Hundred  ...            0.0
#
#              Condo/Coop_Assoc_YN  Central_Air_YN  HOA_YN     Age  Ownership  \
# MLSNumber
# DENC518086                    No             Yes     Yes  1958.0  FeeSimple
# DENC518982                    No             Yes      No  1976.0  FeeSimple
# DENC512992                    No             Yes      No  1985.0  FeeSimple
# DENC512104                    No             Yes     Yes  1985.0  FeeSimple
# DENC503480                    No             Yes      No  1957.0  FeeSimple
# ...                          ...             ...     ...     ...        ...
# DENC2013538                   No             Yes      No  1957.0  FeeSimple
# DENC520114                    No             Yes     Yes  1958.0  FeeSimple
# DENC2014038                   No             Yes      No  1989.0  FeeSimple
# DENC2005484                   No             Yes      No  1992.0  FeeSimple
# DENC526982                    No             Yes     Yes  2002.0  FeeSimple
#
#                      Structure_Type  InteriorSqFt     NumberofStories  \
# MLSNumber
# DENC518086                 Detached        2099.0         Main,Upper1
# DENC518982   Interior Row/Townhouse        1927.0         Main,Upper1
# DENC512992   Interior Row/Townhouse        1150.0         Main,Upper1
# DENC512104   Interior Row/Townhouse        1425.0         Main,Upper1
# DENC503480                 Detached         925.0                Main
# ...                             ...           ...                 ...
# DENC2013538                Detached        2425.0         Lower1,Main
# DENC520114                 Detached        3045.0         Lower1,Main
# DENC2014038                Detached        3191.0  Lower1,Main,Upper1
# DENC2005484                Detached        3425.0  Lower1,Main,Upper1
# DENC526982   Interior Row/Townhouse        1950.0         Main,Upper1
#
#             DaysOnMarket_Buckets
# MLSNumber
# DENC518086    Less than 2 months
# DENC518982    Less than 2 months
# DENC512992    Less than 2 months
# DENC512104    Less than 2 months
# DENC503480    Less than 2 months
# ...                          ...
# DENC2013538   Less than 2 months
# DENC520114    Less than 2 months
# DENC2014038   Less than 2 months
# DENC2005484   Less than 2 months
# DENC526982    Less than 2 months
#
# [5019 rows x 31 columns]

# %%
clean_df.to_csv("binned_data.csv", index=True)

# %%
# Change object columns to category
for label, content in clean_df.items():
    if pd.api.types.is_string_dtype(content):
        clean_df[label] = content.astype("category").cat.as_ordered()
        
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5019 entries, DENC518086 to DENC526982
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Days_on_Market           5019 non-null   float64
#  1   Orig_List_Price          5019 non-null   float64
#  2   Month                    5019 non-null   int64
#  3   Year                     5019 non-null   int64
#  4   Zip_Code                 5019 non-null   category
#  5   SchoolDistrict           5019 non-null   category
#  6   AnnualTax                5019 non-null   int64
#  7   LotAcres                 5019 non-null   float64
#  8   SubdivisionNeighborhood  5019 non-null   category
#  9   Municipality             5019 non-null   category
#  10  Lot                      5019 non-null   category
#  11  OwnerOccupied            5019 non-null   bool
#  12  TotalLandAsmt            5019 non-null   int64
#  13  TotalBldgAsmt            5019 non-null   int64
#  14  PropertyClass            5019 non-null   category
#  15  YearBuilt                5019 non-null   category
#  16  Bedrooms                 5019 non-null   float64
#  17  Baths                    5019 non-null   float64
#  18  Basement_YN              5019 non-null   category
#  19  Garage_YN                5019 non-null   category
#  20  AboveGradeSqFt           5019 non-null   float64
#  21  BelowGradeSqFt           5019 non-null   float64
#  22  Condo/Coop_Assoc_YN      5019 non-null   category
#  23  Central_Air_YN           5019 non-null   category
#  24  HOA_YN                   5019 non-null   category
#  25  Age                      5019 non-null   float64
#  26  Ownership                5019 non-null   category
#  27  Structure_Type           5019 non-null   category
#  28  InteriorSqFt             5019 non-null   float64
#  29  NumberofStories          5019 non-null   category
#  30  DaysOnMarket_Buckets     5019 non-null   category
# dtypes: bool(1), category(16), float64(9), int64(5)
# memory usage: 738.6+ KB

# %%
clean_df.head()
# Out:
#             Days_on_Market  Orig_List_Price  Month  Year Zip_Code  \
# MLSNumber
# DENC518086             5.0         330000.0     12  2020    19808
# DENC518982            47.0         215500.0      1  2021    19808
# DENC512992            15.0         200000.0     12  2020    19808
# DENC512104            11.0         219900.0     10  2020    19808
# DENC503480             3.0         190000.0      6  2020    19808
#
#                    SchoolDistrict  AnnualTax  LotAcres  \
# MLSNumber
# DENC518086  Red Clay Consolidated       2151      0.26
# DENC518982  Red Clay Consolidated       1824      0.06
# DENC512992  Red Clay Consolidated       1563      0.05
# DENC512104  Red Clay Consolidated       2174      0.05
# DENC503480  Red Clay Consolidated       1349      0.17
#
#            SubdivisionNeighborhood        Municipality  ... BelowGradeSqFt  \
# MLSNumber                                               ...
# DENC518086        Sherwood Park Ii  Mill Creek Hundred  ...            0.0
# DENC518982            Pepper Ridge  Mill Creek Hundred  ...          352.0
# DENC512992                Woodmill  Mill Creek Hundred  ...            0.0
# DENC512104           Fairway Falls  Mill Creek Hundred  ...            0.0
# DENC503480         Washington Hgts  Christiana Hundred  ...            0.0
#
#             Condo/Coop_Assoc_YN  Central_Air_YN  HOA_YN     Age  Ownership  \
# MLSNumber
# DENC518086                   No             Yes     Yes  1958.0  FeeSimple
# DENC518982                   No             Yes      No  1976.0  FeeSimple
# DENC512992                   No             Yes      No  1985.0  FeeSimple
# DENC512104                   No             Yes     Yes  1985.0  FeeSimple
# DENC503480                   No             Yes      No  1957.0  FeeSimple
#
#                     Structure_Type  InteriorSqFt NumberofStories  \
# MLSNumber
# DENC518086                Detached        2099.0     Main,Upper1
# DENC518982  Interior Row/Townhouse        1927.0     Main,Upper1
# DENC512992  Interior Row/Townhouse        1150.0     Main,Upper1
# DENC512104  Interior Row/Townhouse        1425.0     Main,Upper1
# DENC503480                Detached         925.0            Main
#
#            DaysOnMarket_Buckets
# MLSNumber
# DENC518086   Less than 2 months
# DENC518982   Less than 2 months
# DENC512992   Less than 2 months
# DENC512104   Less than 2 months
# DENC503480   Less than 2 months
#
# [5 rows x 31 columns]

# %%
# Change categories to numbers
for label,content in clean_df.items():
    if not pd.api.types.is_numeric_dtype(content):
        clean_df[label] = pd.Categorical(content).codes+1

# %%
clean_df.head()
# Out:
#             Days_on_Market  Orig_List_Price  Month  Year  Zip_Code  \
# MLSNumber
# DENC518086             5.0         330000.0     12  2020        13
# DENC518982            47.0         215500.0      1  2021        13
# DENC512992            15.0         200000.0     12  2020        13
# DENC512104            11.0         219900.0     10  2020        13
# DENC503480             3.0         190000.0      6  2020        13
#
#             SchoolDistrict  AnnualTax  LotAcres  SubdivisionNeighborhood  \
# MLSNumber
# DENC518086               4       2151      0.26                      445
# DENC518982               4       1824      0.06                      385
# DENC512992               4       1563      0.05                      600
# DENC512104               4       2174      0.05                      184
# DENC503480               4       1349      0.17                      526
#
#             Municipality  ...  BelowGradeSqFt  Condo/Coop_Assoc_YN  \
# MLSNumber                 ...
# DENC518086             4  ...             0.0                    1
# DENC518982             4  ...           352.0                    1
# DENC512992             4  ...             0.0                    1
# DENC512104             4  ...             0.0                    1
# DENC503480             2  ...             0.0                    1
#
#             Central_Air_YN  HOA_YN     Age  Ownership  Structure_Type  \
# MLSNumber
# DENC518086               2       2  1958.0          3               1
# DENC518982               2       1  1976.0          3               4
# DENC512992               2       1  1985.0          3               4
# DENC512104               2       2  1985.0          3               4
# DENC503480               2       1  1957.0          3               1
#
#             InteriorSqFt  NumberofStories  DaysOnMarket_Buckets
# MLSNumber
# DENC518086        2099.0               27                     1
# DENC518982        1927.0               27                     1
# DENC512992        1150.0               27                     1
# DENC512104        1425.0               27                     1
# DENC503480         925.0               26                     1
#
# [5 rows x 31 columns]

# %%
# Drop rows with null values
clean_df = clean_df.dropna()
clean_df
# Out:
#              Days_on_Market  Orig_List_Price  Month  Year  Zip_Code  \
# MLSNumber
# DENC518086              5.0         330000.0     12  2020        13
# DENC518982             47.0         215500.0      1  2021        13
# DENC512992             15.0         200000.0     12  2020        13
# DENC512104             11.0         219900.0     10  2020        13
# DENC503480              3.0         190000.0      6  2020        13
# ...                     ...              ...    ...   ...       ...
# DENC2013538             5.0         589900.0     12  2021         1
# DENC520114              5.0         595000.0      6  2021         1
# DENC2014038             7.0         529900.0      1  2022         1
# DENC2005484            25.0         620000.0      8  2021         1
# DENC526982             51.0         350000.0      5  2021         1
#
#              SchoolDistrict  AnnualTax  LotAcres  SubdivisionNeighborhood  \
# MLSNumber
# DENC518086                4       2151      0.26                      445
# DENC518982                4       1824      0.06                      385
# DENC512992                4       1563      0.05                      600
# DENC512104                4       2174      0.05                      184
# DENC503480                4       1349      0.17                      526
# ...                     ...        ...       ...                      ...
# DENC2013538               4       3503      0.82                       39
# DENC520114                4       4311      1.03                       83
# DENC2014038               4       4407      0.39                      470
# DENC2005484               4       4825      0.54                      404
# DENC526982                4       3193      0.07                        2
#
#              Municipality  ...  BelowGradeSqFt  Condo/Coop_Assoc_YN  \
# MLSNumber                  ...
# DENC518086              4  ...             0.0                    1
# DENC518982              4  ...           352.0                    1
# DENC512992              4  ...             0.0                    1
# DENC512104              4  ...             0.0                    1
# DENC503480              2  ...             0.0                    1
# ...                   ...  ...             ...                  ...
# DENC2013538             4  ...             0.0                    1
# DENC520114              4  ...             0.0                    1
# DENC2014038             4  ...           341.0                    1
# DENC2005484             4  ...             0.0                    1
# DENC526982              4  ...             0.0                    1
#
#              Central_Air_YN  HOA_YN     Age  Ownership  Structure_Type  \
# MLSNumber
# DENC518086                2       2  1958.0          3               1
# DENC518982                2       1  1976.0          3               4
# DENC512992                2       1  1985.0          3               4
# DENC512104                2       2  1985.0          3               4
# DENC503480                2       1  1957.0          3               1
# ...                     ...     ...     ...        ...             ...
# DENC2013538               2       1  1957.0          3               1
# DENC520114                2       2  1958.0          3               1
# DENC2014038               2       1  1989.0          3               1
# DENC2005484               2       1  1992.0          3               1
# DENC526982                2       2  2002.0          3               4
#
#              InteriorSqFt  NumberofStories  DaysOnMarket_Buckets
# MLSNumber
# DENC518086         2099.0               27                     1
# DENC518982         1927.0               27                     1
# DENC512992         1150.0               27                     1
# DENC512104         1425.0               27                     1
# DENC503480          925.0               26                     1
# ...                   ...              ...                   ...
# DENC2013538        2425.0               11                     1
# DENC520114         3045.0               11                     1
# DENC2014038        3191.0               12                     1
# DENC2005484        3425.0               12                     1
# DENC526982         1950.0               27                     1
#
# [5019 rows x 31 columns]

# %%
clean_df.columns
# Out:
# Index(['Days_on_Market', 'Orig_List_Price', 'Month', 'Year', 'Zip_Code',
#        'SchoolDistrict', 'AnnualTax', 'LotAcres', 'SubdivisionNeighborhood',
#        'Municipality', 'Lot', 'OwnerOccupied', 'TotalLandAsmt',
#        'TotalBldgAsmt', 'PropertyClass', 'YearBuilt', 'Bedrooms', 'Baths',
#        'Basement_YN', 'Garage_YN', 'AboveGradeSqFt', 'BelowGradeSqFt',
#        'Condo/Coop_Assoc_YN', 'Central_Air_YN', 'HOA_YN', 'Age', 'Ownership',
#        'Structure_Type', 'InteriorSqFt', 'NumberofStories',
#        'DaysOnMarket_Buckets'],
#       dtype='object')

# %%
import seaborn as sns

corr = clean_df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
y = clean_df["DaysOnMarket_Buckets"]
X = clean_df.drop(columns=["Days_on_Market", "DaysOnMarket_Buckets"])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)
X_train.shape
# Out:
# (3764, 29)

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
brf = BalancedRandomForestClassifier(n_estimators=1000, random_state=50)
brf.fit(X_train, y_train)
# Out:
# BalancedRandomForestClassifier(n_estimators=1000, random_state=50)

# %%
# Calculated the balanced accuracy score
y_pred = brf.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.7219178727278435

# %%
import pickle

# %%
filename = "BRF_DOM.sav"
pickle.dump(brf, open(filename, "wb"))

# %% [markdown]
# ```
# //load the model from disk
# loaded_model = pickle.load(open(filename, ‘rb’))
# result = loaded_model.score(X_test, Y_test)
# print(result)
# ```

# %%
# List the features sorted in descending order by feature importance
sorted(zip(brf.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.07292443236259165, 'AnnualTax'),
#  (0.07106289798067397, 'Orig_List_Price'),
#  (0.06516531625614749, 'SubdivisionNeighborhood'),
#  (0.062382999583681466, 'Lot'),
#  (0.06195934122141694, 'TotalLandAsmt'),
#  (0.0609020844282735, 'TotalBldgAsmt'),
#  (0.056283012489741685, 'Month'),
#  (0.053741193592295435, 'YearBuilt'),
#  (0.05252922964424796, 'Age'),
#  (0.05234453019804979, 'LotAcres'),
#  (0.05225631423103535, 'AboveGradeSqFt'),
#  (0.05193476683891511, 'InteriorSqFt'),
#  (0.04970094525240412, 'Year'),
#  (0.03395852749553868, 'NumberofStories'),
#  (0.027990468690802427, 'Zip_Code'),
#  (0.027458632195624885, 'Municipality'),
#  (0.02285219415167535, 'BelowGradeSqFt'),
#  (0.020866790456148997, 'Bedrooms'),
#  (0.019877667594419085, 'Structure_Type'),
#  (0.01721851259041715, 'Baths'),
#  (0.015195318710185866, 'Central_Air_YN'),
#  (0.013706037888142699, 'SchoolDistrict'),
#  (0.010014638238654096, 'Garage_YN'),
#  (0.00845484669813645, 'HOA_YN'),
#  (0.007217427821339865, 'OwnerOccupied'),
#  (0.005638818594078507, 'Basement_YN'),
#  (0.002978474458373747, 'Ownership'),
#  (0.0029703368656945725, 'Condo/Coop_Assoc_YN'),
#  (0.00041424347129309224, 'PropertyClass')]

# %%
# Drop columns from clean_df
updated_df = clean_df.drop(columns=["PropertyClass", "Condo/Coop_Assoc_YN", "Ownership", "OwnerOccupied", "HOA_YN", "Basement_YN", "Central_Air_YN"])
updated_df
# Out:
#              Days_on_Market  Orig_List_Price  Month  Year  Zip_Code  \
# MLSNumber
# DENC518086              5.0         330000.0     12  2020        13
# DENC518982             47.0         215500.0      1  2021        13
# DENC512992             15.0         200000.0     12  2020        13
# DENC512104             11.0         219900.0     10  2020        13
# DENC503480              3.0         190000.0      6  2020        13
# ...                     ...              ...    ...   ...       ...
# DENC2013538             5.0         589900.0     12  2021         1
# DENC520114              5.0         595000.0      6  2021         1
# DENC2014038             7.0         529900.0      1  2022         1
# DENC2005484            25.0         620000.0      8  2021         1
# DENC526982             51.0         350000.0      5  2021         1
#
#              SchoolDistrict  AnnualTax  LotAcres  SubdivisionNeighborhood  \
# MLSNumber
# DENC518086                4       2151      0.26                      445
# DENC518982                4       1824      0.06                      385
# DENC512992                4       1563      0.05                      600
# DENC512104                4       2174      0.05                      184
# DENC503480                4       1349      0.17                      526
# ...                     ...        ...       ...                      ...
# DENC2013538               4       3503      0.82                       39
# DENC520114                4       4311      1.03                       83
# DENC2014038               4       4407      0.39                      470
# DENC2005484               4       4825      0.54                      404
# DENC526982                4       3193      0.07                        2
#
#              Municipality  ...  Bedrooms  Baths  Garage_YN  AboveGradeSqFt  \
# MLSNumber                  ...
# DENC518086              4  ...       4.0    2.0          2          2099.0
# DENC518982              4  ...       3.0    2.0          1          1575.0
# DENC512992              4  ...       2.0    2.0          1          1150.0
# DENC512104              4  ...       2.0    3.0          2          1425.0
# DENC503480              2  ...       3.0    2.0          1           925.0
# ...                   ...  ...       ...    ...        ...             ...
# DENC2013538             4  ...       4.0    2.0          2          2425.0
# DENC520114              4  ...       3.0    2.0          2          3045.0
# DENC2014038             4  ...       4.0    3.0          2          2850.0
# DENC2005484             4  ...       4.0    3.0          2          3425.0
# DENC526982              4  ...       2.0    2.0          2          1950.0
#
#              BelowGradeSqFt     Age  Structure_Type  InteriorSqFt  \
# MLSNumber
# DENC518086              0.0  1958.0               1        2099.0
# DENC518982            352.0  1976.0               4        1927.0
# DENC512992              0.0  1985.0               4        1150.0
# DENC512104              0.0  1985.0               4        1425.0
# DENC503480              0.0  1957.0               1         925.0
# ...                     ...     ...             ...           ...
# DENC2013538             0.0  1957.0               1        2425.0
# DENC520114              0.0  1958.0               1        3045.0
# DENC2014038           341.0  1989.0               1        3191.0
# DENC2005484             0.0  1992.0               1        3425.0
# DENC526982              0.0  2002.0               4        1950.0
#
#              NumberofStories  DaysOnMarket_Buckets
# MLSNumber
# DENC518086                27                     1
# DENC518982                27                     1
# DENC512992                27                     1
# DENC512104                27                     1
# DENC503480                26                     1
# ...                      ...                   ...
# DENC2013538               11                     1
# DENC520114                11                     1
# DENC2014038               12                     1
# DENC2005484               12                     1
# DENC526982                27                     1
#
# [5019 rows x 24 columns]

# %%
y = updated_df["DaysOnMarket_Buckets"]
X = updated_df.drop(columns=["Days_on_Market", "DaysOnMarket_Buckets"])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)
X_train.shape
# Out:
# (3764, 22)

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
brf2 = BalancedRandomForestClassifier(n_estimators=1000, random_state=50)
brf2.fit(X_train, y_train)
# Out:
# BalancedRandomForestClassifier(n_estimators=1000, random_state=50)

# %%
# Calculated the balanced accuracy score
y_pred = brf2.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.6894062919624018

# %%
filename = "BRF_DOM.sav"
pickle.dump(brf2, open(filename, "wb"))

# %%
# List the features sorted in descending order by feature importance
sorted(zip(brf2.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.08103218537766144, 'AnnualTax'),
#  (0.07752327555854614, 'TotalLandAsmt'),
#  (0.06935863288583419, 'Orig_List_Price'),
#  (0.06860685612415672, 'TotalBldgAsmt'),
#  (0.06552825084914665, 'LotAcres'),
#  (0.061049646353064195, 'SubdivisionNeighborhood'),
#  (0.060362556179296166, 'Lot'),
#  (0.05997353424353763, 'YearBuilt'),
#  (0.05890180195654185, 'Age'),
#  (0.052632751394833845, 'InteriorSqFt'),
#  (0.04986945985385009, 'AboveGradeSqFt'),
#  (0.04889484360932226, 'Month'),
#  (0.04750428058565317, 'Year'),
#  (0.03182972454435394, 'NumberofStories'),
#  (0.029993009535216077, 'Structure_Type'),
#  (0.028936922857264007, 'Municipality'),
#  (0.028005963106476524, 'Zip_Code'),
#  (0.021951795704204642, 'BelowGradeSqFt'),
#  (0.019331231697373455, 'Bedrooms'),
#  (0.01682657774789373, 'Baths'),
#  (0.013098719411839042, 'SchoolDistrict'),
#  (0.008787980423934291, 'Garage_YN')]

# %%
def feature_plot(columns, importance, n=10):
    df = (pd.DataFrame({"features" : columns,
                        "feature_importances" : importance}).sort_values("feature_importances",ascending=False).reset_index(drop=True))
    return df

# %%
pf = feature_plot(X_train.columns, brf2.feature_importances_)

# %% [markdown]
# ### Visualizations and Export Model

# %%
fig , ax = plt.subplots()
ax.barh(pf["features"] , pf["feature_importances"])
ax.invert_yaxis()

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[849, 354],
#        [ 17,  35]], dtype=int64)

# %%
pf
# Out:
#                    features  feature_importances
# 0                 AnnualTax             0.081032
# 1             TotalLandAsmt             0.077523
# 2           Orig_List_Price             0.069359
# 3             TotalBldgAsmt             0.068607
# 4                  LotAcres             0.065528
# 5   SubdivisionNeighborhood             0.061050
# 6                       Lot             0.060363
# 7                 YearBuilt             0.059974
# 8                       Age             0.058902
# 9              InteriorSqFt             0.052633
# 10           AboveGradeSqFt             0.049869
# 11                    Month             0.048895
# 12                     Year             0.047504
# 13          NumberofStories             0.031830
# 14           Structure_Type             0.029993
# 15             Municipality             0.028937
# 16                 Zip_Code             0.028006
# 17           BelowGradeSqFt             0.021952
# 18                 Bedrooms             0.019331
# 19                    Baths             0.016827
# 20           SchoolDistrict             0.013099
# 21                Garage_YN             0.008788

# %%
updated_df
# Out:
#              Days_on_Market  Orig_List_Price  Month  Year  Zip_Code  \
# MLSNumber
# DENC518086              5.0         330000.0     12  2020        13
# DENC518982             47.0         215500.0      1  2021        13
# DENC512992             15.0         200000.0     12  2020        13
# DENC512104             11.0         219900.0     10  2020        13
# DENC503480              3.0         190000.0      6  2020        13
# ...                     ...              ...    ...   ...       ...
# DENC2013538             5.0         589900.0     12  2021         1
# DENC520114              5.0         595000.0      6  2021         1
# DENC2014038             7.0         529900.0      1  2022         1
# DENC2005484            25.0         620000.0      8  2021         1
# DENC526982             51.0         350000.0      5  2021         1
#
#              SchoolDistrict  AnnualTax  LotAcres  SubdivisionNeighborhood  \
# MLSNumber
# DENC518086                4       2151      0.26                      445
# DENC518982                4       1824      0.06                      385
# DENC512992                4       1563      0.05                      600
# DENC512104                4       2174      0.05                      184
# DENC503480                4       1349      0.17                      526
# ...                     ...        ...       ...                      ...
# DENC2013538               4       3503      0.82                       39
# DENC520114                4       4311      1.03                       83
# DENC2014038               4       4407      0.39                      470
# DENC2005484               4       4825      0.54                      404
# DENC526982                4       3193      0.07                        2
#
#              Municipality  ...  Bedrooms  Baths  Garage_YN  AboveGradeSqFt  \
# MLSNumber                  ...
# DENC518086              4  ...       4.0    2.0          2          2099.0
# DENC518982              4  ...       3.0    2.0          1          1575.0
# DENC512992              4  ...       2.0    2.0          1          1150.0
# DENC512104              4  ...       2.0    3.0          2          1425.0
# DENC503480              2  ...       3.0    2.0          1           925.0
# ...                   ...  ...       ...    ...        ...             ...
# DENC2013538             4  ...       4.0    2.0          2          2425.0
# DENC520114              4  ...       3.0    2.0          2          3045.0
# DENC2014038             4  ...       4.0    3.0          2          2850.0
# DENC2005484             4  ...       4.0    3.0          2          3425.0
# DENC526982              4  ...       2.0    2.0          2          1950.0
#
#              BelowGradeSqFt     Age  Structure_Type  InteriorSqFt  \
# MLSNumber
# DENC518086              0.0  1958.0               1        2099.0
# DENC518982            352.0  1976.0               4        1927.0
# DENC512992              0.0  1985.0               4        1150.0
# DENC512104              0.0  1985.0               4        1425.0
# DENC503480              0.0  1957.0               1         925.0
# ...                     ...     ...             ...           ...
# DENC2013538             0.0  1957.0               1        2425.0
# DENC520114              0.0  1958.0               1        3045.0
# DENC2014038           341.0  1989.0               1        3191.0
# DENC2005484             0.0  1992.0               1        3425.0
# DENC526982              0.0  2002.0               4        1950.0
#
#              NumberofStories  DaysOnMarket_Buckets
# MLSNumber
# DENC518086                27                     1
# DENC518982                27                     1
# DENC512992                27                     1
# DENC512104                27                     1
# DENC503480                26                     1
# ...                      ...                   ...
# DENC2013538               11                     1
# DENC520114                11                     1
# DENC2014038               12                     1
# DENC2005484               12                     1
# DENC526982                27                     1
#
# [5019 rows x 24 columns]

# %%
updated_df.to_csv("updated_df.csv")

# %%
test_pred = brf2.predict(updated_df.drop(columns=["Days_on_Market", "DaysOnMarket_Buckets"]))

# %%
test_pred
# Out:
# array([1, 2, 1, ..., 1, 2, 1], dtype=int8)

# %%
clean_df
# Out:
#              Days_on_Market  Orig_List_Price  Month  Year  Zip_Code  \
# MLSNumber
# DENC518086              5.0         330000.0     12  2020        13
# DENC518982             47.0         215500.0      1  2021        13
# DENC512992             15.0         200000.0     12  2020        13
# DENC512104             11.0         219900.0     10  2020        13
# DENC503480              3.0         190000.0      6  2020        13
# ...                     ...              ...    ...   ...       ...
# DENC2013538             5.0         589900.0     12  2021         1
# DENC520114              5.0         595000.0      6  2021         1
# DENC2014038             7.0         529900.0      1  2022         1
# DENC2005484            25.0         620000.0      8  2021         1
# DENC526982             51.0         350000.0      5  2021         1
#
#              SchoolDistrict  AnnualTax  LotAcres  SubdivisionNeighborhood  \
# MLSNumber
# DENC518086                4       2151      0.26                      445
# DENC518982                4       1824      0.06                      385
# DENC512992                4       1563      0.05                      600
# DENC512104                4       2174      0.05                      184
# DENC503480                4       1349      0.17                      526
# ...                     ...        ...       ...                      ...
# DENC2013538               4       3503      0.82                       39
# DENC520114                4       4311      1.03                       83
# DENC2014038               4       4407      0.39                      470
# DENC2005484               4       4825      0.54                      404
# DENC526982                4       3193      0.07                        2
#
#              Municipality  ...  BelowGradeSqFt  Condo/Coop_Assoc_YN  \
# MLSNumber                  ...
# DENC518086              4  ...             0.0                    1
# DENC518982              4  ...           352.0                    1
# DENC512992              4  ...             0.0                    1
# DENC512104              4  ...             0.0                    1
# DENC503480              2  ...             0.0                    1
# ...                   ...  ...             ...                  ...
# DENC2013538             4  ...             0.0                    1
# DENC520114              4  ...             0.0                    1
# DENC2014038             4  ...           341.0                    1
# DENC2005484             4  ...             0.0                    1
# DENC526982              4  ...             0.0                    1
#
#              Central_Air_YN  HOA_YN     Age  Ownership  Structure_Type  \
# MLSNumber
# DENC518086                2       2  1958.0          3               1
# DENC518982                2       1  1976.0          3               4
# DENC512992                2       1  1985.0          3               4
# DENC512104                2       2  1985.0          3               4
# DENC503480                2       1  1957.0          3               1
# ...                     ...     ...     ...        ...             ...
# DENC2013538               2       1  1957.0          3               1
# DENC520114                2       2  1958.0          3               1
# DENC2014038               2       1  1989.0          3               1
# DENC2005484               2       1  1992.0          3               1
# DENC526982                2       2  2002.0          3               4
#
#              InteriorSqFt  NumberofStories  DaysOnMarket_Buckets
# MLSNumber
# DENC518086         2099.0               27                     1
# DENC518982         1927.0               27                     1
# DENC512992         1150.0               27                     1
# DENC512104         1425.0               27                     1
# DENC503480          925.0               26                     1
# ...                   ...              ...                   ...
# DENC2013538        2425.0               11                     1
# DENC520114         3045.0               11                     1
# DENC2014038        3191.0               12                     1
# DENC2005484        3425.0               12                     1
# DENC526982         1950.0               27                     1
#
# [5019 rows x 31 columns]

# %%
binned_df = pd.read_csv("binned_data.csv")
binned_df
# Out:
#         MLSNumber  Days_on_Market  Orig_List_Price  Month  Year  Zip_Code  \
# 0      DENC518086             5.0         330000.0     12  2020     19808
# 1      DENC518982            47.0         215500.0      1  2021     19808
# 2      DENC512992            15.0         200000.0     12  2020     19808
# 3      DENC512104            11.0         219900.0     10  2020     19808
# 4      DENC503480             3.0         190000.0      6  2020     19808
# ...           ...             ...              ...    ...   ...       ...
# 5014  DENC2013538             5.0         589900.0     12  2021     19707
# 5015   DENC520114             5.0         595000.0      6  2021     19707
# 5016  DENC2014038             7.0         529900.0      1  2022     19707
# 5017  DENC2005484            25.0         620000.0      8  2021     19707
# 5018   DENC526982            51.0         350000.0      5  2021     19707
#
#              SchoolDistrict  AnnualTax  LotAcres SubdivisionNeighborhood  ...  \
# 0     Red Clay Consolidated       2151      0.26        Sherwood Park Ii  ...
# 1     Red Clay Consolidated       1824      0.06            Pepper Ridge  ...
# 2     Red Clay Consolidated       1563      0.05                Woodmill  ...
# 3     Red Clay Consolidated       2174      0.05           Fairway Falls  ...
# 4     Red Clay Consolidated       1349      0.17         Washington Hgts  ...
# ...                     ...        ...       ...                     ...  ...
# 5014  Red Clay Consolidated       3503      0.82          Berkeley Ridge  ...
# 5015  Red Clay Consolidated       4311      1.03        Canterbury Hills  ...
# 5016  Red Clay Consolidated       4407      0.39          Stenning Woods  ...
# 5017  Red Clay Consolidated       4825      0.54       Quaker Lea Villas  ...
# 5018  Red Clay Consolidated       3193      0.07           Adare Village  ...
#
#      BelowGradeSqFt Condo/Coop_Assoc_YN  Central_Air_YN  HOA_YN     Age  \
# 0               0.0                  No             Yes     Yes  1958.0
# 1             352.0                  No             Yes      No  1976.0
# 2               0.0                  No             Yes      No  1985.0
# 3               0.0                  No             Yes     Yes  1985.0
# 4               0.0                  No             Yes      No  1957.0
# ...             ...                 ...             ...     ...     ...
# 5014            0.0                  No             Yes      No  1957.0
# 5015            0.0                  No             Yes     Yes  1958.0
# 5016          341.0                  No             Yes      No  1989.0
# 5017            0.0                  No             Yes      No  1992.0
# 5018            0.0                  No             Yes     Yes  2002.0
#
#       Ownership          Structure_Type  InteriorSqFt     NumberofStories  \
# 0     FeeSimple                Detached        2099.0         Main,Upper1
# 1     FeeSimple  Interior Row/Townhouse        1927.0         Main,Upper1
# 2     FeeSimple  Interior Row/Townhouse        1150.0         Main,Upper1
# 3     FeeSimple  Interior Row/Townhouse        1425.0         Main,Upper1
# 4     FeeSimple                Detached         925.0                Main
# ...         ...                     ...           ...                 ...
# 5014  FeeSimple                Detached        2425.0         Lower1,Main
# 5015  FeeSimple                Detached        3045.0         Lower1,Main
# 5016  FeeSimple                Detached        3191.0  Lower1,Main,Upper1
# 5017  FeeSimple                Detached        3425.0  Lower1,Main,Upper1
# 5018  FeeSimple  Interior Row/Townhouse        1950.0         Main,Upper1
#
#      DaysOnMarket_Buckets
# 0      Less than 2 months
# 1      Less than 2 months
# 2      Less than 2 months
# 3      Less than 2 months
# 4      Less than 2 months
# ...                   ...
# 5014   Less than 2 months
# 5015   Less than 2 months
# 5016   Less than 2 months
# 5017   Less than 2 months
# 5018   Less than 2 months
#
# [5019 rows x 32 columns]

# %%
binned_df['Predicted_DOM'] = test_pred
binned_df
# Out:
#         MLSNumber  Days_on_Market  Orig_List_Price  Month  Year  Zip_Code  \
# 0      DENC518086             5.0         330000.0     12  2020     19808
# 1      DENC518982            47.0         215500.0      1  2021     19808
# 2      DENC512992            15.0         200000.0     12  2020     19808
# 3      DENC512104            11.0         219900.0     10  2020     19808
# 4      DENC503480             3.0         190000.0      6  2020     19808
# ...           ...             ...              ...    ...   ...       ...
# 5014  DENC2013538             5.0         589900.0     12  2021     19707
# 5015   DENC520114             5.0         595000.0      6  2021     19707
# 5016  DENC2014038             7.0         529900.0      1  2022     19707
# 5017  DENC2005484            25.0         620000.0      8  2021     19707
# 5018   DENC526982            51.0         350000.0      5  2021     19707
#
#              SchoolDistrict  AnnualTax  LotAcres SubdivisionNeighborhood  ...  \
# 0     Red Clay Consolidated       2151      0.26        Sherwood Park Ii  ...
# 1     Red Clay Consolidated       1824      0.06            Pepper Ridge  ...
# 2     Red Clay Consolidated       1563      0.05                Woodmill  ...
# 3     Red Clay Consolidated       2174      0.05           Fairway Falls  ...
# 4     Red Clay Consolidated       1349      0.17         Washington Hgts  ...
# ...                     ...        ...       ...                     ...  ...
# 5014  Red Clay Consolidated       3503      0.82          Berkeley Ridge  ...
# 5015  Red Clay Consolidated       4311      1.03        Canterbury Hills  ...
# 5016  Red Clay Consolidated       4407      0.39          Stenning Woods  ...
# 5017  Red Clay Consolidated       4825      0.54       Quaker Lea Villas  ...
# 5018  Red Clay Consolidated       3193      0.07           Adare Village  ...
#
#      Condo/Coop_Assoc_YN Central_Air_YN  HOA_YN     Age  Ownership  \
# 0                     No            Yes     Yes  1958.0  FeeSimple
# 1                     No            Yes      No  1976.0  FeeSimple
# 2                     No            Yes      No  1985.0  FeeSimple
# 3                     No            Yes     Yes  1985.0  FeeSimple
# 4                     No            Yes      No  1957.0  FeeSimple
# ...                  ...            ...     ...     ...        ...
# 5014                  No            Yes      No  1957.0  FeeSimple
# 5015                  No            Yes     Yes  1958.0  FeeSimple
# 5016                  No            Yes      No  1989.0  FeeSimple
# 5017                  No            Yes      No  1992.0  FeeSimple
# 5018                  No            Yes     Yes  2002.0  FeeSimple
#
#               Structure_Type  InteriorSqFt     NumberofStories  \
# 0                   Detached        2099.0         Main,Upper1
# 1     Interior Row/Townhouse        1927.0         Main,Upper1
# 2     Interior Row/Townhouse        1150.0         Main,Upper1
# 3     Interior Row/Townhouse        1425.0         Main,Upper1
# 4                   Detached         925.0                Main
# ...                      ...           ...                 ...
# 5014                Detached        2425.0         Lower1,Main
# 5015                Detached        3045.0         Lower1,Main
# 5016                Detached        3191.0  Lower1,Main,Upper1
# 5017                Detached        3425.0  Lower1,Main,Upper1
# 5018  Interior Row/Townhouse        1950.0         Main,Upper1
#
#       DaysOnMarket_Buckets Predicted_DOM
# 0       Less than 2 months             1
# 1       Less than 2 months             2
# 2       Less than 2 months             1
# 3       Less than 2 months             2
# 4       Less than 2 months             1
# ...                    ...           ...
# 5014    Less than 2 months             1
# 5015    Less than 2 months             2
# 5016    Less than 2 months             1
# 5017    Less than 2 months             2
# 5018    Less than 2 months             1
#
# [5019 rows x 33 columns]

# %%
binned_df['Predicted_DOM'] = binned_df['Predicted_DOM'].replace([1],'Less than 2 months')
binned_df['Predicted_DOM'] = binned_df['Predicted_DOM'].replace([2],'More than 2 months')
binned_df
# Out:
#         MLSNumber  Days_on_Market  Orig_List_Price  Month  Year  Zip_Code  \
# 0      DENC518086             5.0         330000.0     12  2020     19808
# 1      DENC518982            47.0         215500.0      1  2021     19808
# 2      DENC512992            15.0         200000.0     12  2020     19808
# 3      DENC512104            11.0         219900.0     10  2020     19808
# 4      DENC503480             3.0         190000.0      6  2020     19808
# ...           ...             ...              ...    ...   ...       ...
# 5014  DENC2013538             5.0         589900.0     12  2021     19707
# 5015   DENC520114             5.0         595000.0      6  2021     19707
# 5016  DENC2014038             7.0         529900.0      1  2022     19707
# 5017  DENC2005484            25.0         620000.0      8  2021     19707
# 5018   DENC526982            51.0         350000.0      5  2021     19707
#
#              SchoolDistrict  AnnualTax  LotAcres SubdivisionNeighborhood  ...  \
# 0     Red Clay Consolidated       2151      0.26        Sherwood Park Ii  ...
# 1     Red Clay Consolidated       1824      0.06            Pepper Ridge  ...
# 2     Red Clay Consolidated       1563      0.05                Woodmill  ...
# 3     Red Clay Consolidated       2174      0.05           Fairway Falls  ...
# 4     Red Clay Consolidated       1349      0.17         Washington Hgts  ...
# ...                     ...        ...       ...                     ...  ...
# 5014  Red Clay Consolidated       3503      0.82          Berkeley Ridge  ...
# 5015  Red Clay Consolidated       4311      1.03        Canterbury Hills  ...
# 5016  Red Clay Consolidated       4407      0.39          Stenning Woods  ...
# 5017  Red Clay Consolidated       4825      0.54       Quaker Lea Villas  ...
# 5018  Red Clay Consolidated       3193      0.07           Adare Village  ...
#
#      Condo/Coop_Assoc_YN Central_Air_YN  HOA_YN     Age  Ownership  \
# 0                     No            Yes     Yes  1958.0  FeeSimple
# 1                     No            Yes      No  1976.0  FeeSimple
# 2                     No            Yes      No  1985.0  FeeSimple
# 3                     No            Yes     Yes  1985.0  FeeSimple
# 4                     No            Yes      No  1957.0  FeeSimple
# ...                  ...            ...     ...     ...        ...
# 5014                  No            Yes      No  1957.0  FeeSimple
# 5015                  No            Yes     Yes  1958.0  FeeSimple
# 5016                  No            Yes      No  1989.0  FeeSimple
# 5017                  No            Yes      No  1992.0  FeeSimple
# 5018                  No            Yes     Yes  2002.0  FeeSimple
#
#               Structure_Type  InteriorSqFt     NumberofStories  \
# 0                   Detached        2099.0         Main,Upper1
# 1     Interior Row/Townhouse        1927.0         Main,Upper1
# 2     Interior Row/Townhouse        1150.0         Main,Upper1
# 3     Interior Row/Townhouse        1425.0         Main,Upper1
# 4                   Detached         925.0                Main
# ...                      ...           ...                 ...
# 5014                Detached        2425.0         Lower1,Main
# 5015                Detached        3045.0         Lower1,Main
# 5016                Detached        3191.0  Lower1,Main,Upper1
# 5017                Detached        3425.0  Lower1,Main,Upper1
# 5018  Interior Row/Townhouse        1950.0         Main,Upper1
#
#       DaysOnMarket_Buckets       Predicted_DOM
# 0       Less than 2 months  Less than 2 months
# 1       Less than 2 months  More than 2 months
# 2       Less than 2 months  Less than 2 months
# 3       Less than 2 months  More than 2 months
# 4       Less than 2 months  Less than 2 months
# ...                    ...                 ...
# 5014    Less than 2 months  Less than 2 months
# 5015    Less than 2 months  More than 2 months
# 5016    Less than 2 months  Less than 2 months
# 5017    Less than 2 months  More than 2 months
# 5018    Less than 2 months  Less than 2 months
#
# [5019 rows x 33 columns]

# %%
binned_df.sample(10)
# Out:
#         MLSNumber  Days_on_Market  Orig_List_Price  Month  Year  Zip_Code  \
# 3971   DENC518818             8.0         225000.0      1  2021     19711
# 4685  DENC2000920            12.0         492500.0      6  2021     19711
# 1985  DENC2022372            10.0         207900.0      4  2022     19804
# 2700   DENC513010             6.0         200000.0     11  2020     19802
# 4247   DENC501992            75.0         449500.0      5  2020     19711
# 1478   DENC522864             4.0         284900.0      3  2021     19805
# 79     DENC523336             6.0         235000.0      4  2021     19808
# 984    DENC521858             5.0         279900.0      3  2021     19806
# 3463  DENC2004906            42.0         205000.0      8  2021     19720
# 1029   DENC520858             2.0         329900.0      2  2021     19806
#
#              SchoolDistrict  AnnualTax  LotAcres SubdivisionNeighborhood  ...  \
# 3971              Christina       2673      0.33          Old Mill Manor  ...
# 4685              Christina       5024      0.37      Middle Run Crossin  ...
# 1985  Red Clay Consolidated       1250      0.08          Pleasant Hills  ...
# 2700             Brandywine       2381      0.05                Wilm #03  ...
# 4247              Christina       5293      0.71              Beech Hill  ...
# 1478  Red Clay Consolidated       2065      0.22           Woodland Park  ...
# 79    Red Clay Consolidated       1676      0.15       Faulkland Heights  ...
# 984   Red Clay Consolidated       2381      0.04                Wilm #11  ...
# 3463               Colonial       1233      0.15           Swanwyck Ests  ...
# 1029  Red Clay Consolidated       3173      0.04                Wilm #12  ...
#
#      Condo/Coop_Assoc_YN Central_Air_YN  HOA_YN     Age  Ownership  \
# 3971                  No            Yes     Yes  1966.0  FeeSimple
# 4685                  No            Yes     Yes  1994.0  FeeSimple
# 1985                  No            Yes      No  1944.0  FeeSimple
# 2700                  No            Yes      No  1971.0  FeeSimple
# 4247                  No            Yes     Yes  1987.0  FeeSimple
# 1478                  No            Yes      No  1960.0  FeeSimple
# 79                    No            Yes      No  1960.0  FeeSimple
# 984                   No            Yes      No  1890.0  FeeSimple
# 3463                  No            Yes      No  1955.0  FeeSimple
# 1029                  No            Yes      No  1907.0  FeeSimple
#
#               Structure_Type  InteriorSqFt     NumberofStories  \
# 3971                Detached        2268.0                Main
# 4685                Detached        3881.0  Lower1,Main,Upper1
# 1985      Twin/Semi-Detached         875.0         Main,Upper1
# 2700    End of Row/Townhouse        1831.0  Lower1,Main,Upper1
# 4247                Detached        2650.0         Main,Upper1
# 1478                Detached        1650.0  Main,Upper1,Upper2
# 79                  Detached        1000.0                Main
# 984   Interior Row/Townhouse        1400.0                Main
# 3463                Detached         900.0                Main
# 1029      Twin/Semi-Detached        1925.0  Main,Upper1,Upper2
#
#       DaysOnMarket_Buckets       Predicted_DOM
# 3971    Less than 2 months  Less than 2 months
# 4685    Less than 2 months  Less than 2 months
# 1985    Less than 2 months  Less than 2 months
# 2700    Less than 2 months  More than 2 months
# 4247    More than 2 months  More than 2 months
# 1478    Less than 2 months  Less than 2 months
# 79      Less than 2 months  Less than 2 months
# 984     Less than 2 months  More than 2 months
# 3463    Less than 2 months  Less than 2 months
# 1029    Less than 2 months  More than 2 months
#
# [10 rows x 33 columns]

# %%
binned_df.to_csv("predicted_df.csv")

# %%
from sklearn import datasets
from sklearn.ensemble import GradientBoostingClassifier
import scikitplot as skplt

# %%
skplt.metrics.plot_confusion_matrix(y_test, y_pred, normalize=False, title = 'Confusion Matrix')
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>

# %%
skplt.metrics.plot_confusion_matrix(y_test, y_pred, normalize=True, title = 'Confusion Matrix')
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>
